# %%
from PIL import Image

# %%
word_matrix = Image.open("word_matrix.jpg")

# %%
word_matrix
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1015x559>

# %%
mask1 = Image.open("mask.jpg")

# %%
mask1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=505x251>

# %%
word_matrix.size
# Out:
# (1015, 559)

# %%
mask1.size
# Out:
# (505, 251)

# %%
mask1.resize((1015, 559))
# Out:
# <PIL.Image.Image image mode=RGB size=1015x559>

# %%
word_matrix
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1015x559>

# %%
mask1.putalpha(100)

# %%
mask1.save("new_mask.png")

# %%
new_mask = Image.open("new_mask.png")

# %%
new_mask = new_mask.resize((1015, 559))
new_mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559>

# %%
word_matrix.paste(im=new_mask, box=(0,0), mask=new_mask)

# %%
new_mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559>

# %%
word_matrix
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1015x559>

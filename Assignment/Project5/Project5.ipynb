# %%
import gdown
import re
import PyPDF2
import os
import mysql.connector

# Download file from Google Drive
def download_file(work_folder, actual_download_link_url):
    save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    
    try:
        gdown.download(actual_download_link_url, save_file_path, quiet=False)
        print(f"File downloaded successfully at path :{save_file_path}")
    except Exception as e:
        if not os.path.exists(work_folder):
            os.makedirs(work_folder)
        gdown.download(actual_download_link_url, save_file_path, quiet=True)
        print(f"File downloaded successfully at path :{save_file_path}")

# Connect to MySQL Database
def connect_to_mysql_database():
    try:
        connection = mysql.connector.connect(
            host="localhost", 
            user="priya", 
            password="priya", 
            database="mydatabase"
        )
        if connection.is_connected():
            print("Connection to MySQL DB is successful!")
            return connection
    except Exception as e:
        print("Error while connecting to MySQL DB:", e)
        return None

# Check if DB exists or not
def create_db_if_not_exists(connection):
    try:
        cursor = connection.cursor()
        cursor.execute("CREATE DATABASE IF NOT EXISTS mydatabase;")
    except Exception as e:
        print("Error while creating DB:", e)
        return None

# Create table if it doesn't exist
def create_table_if_not_exists(connection):
    cursor = connection.cursor()
    create_table_query = """
    CREATE TABLE IF NOT EXISTS QUESTIONS (
        id INT AUTO_INCREMENT PRIMARY KEY,
        subject_name VARCHAR(100),
        question_text TEXT,
        answer_options TEXT,
        correct_answer VARCHAR(10),
        chapter_name VARCHAR(100)
    );
    """
    cursor.execute(create_table_query)
    connection.commit()

# Extract questions and answers from PDF
def extract_questions_from_pdf(pdf_path):
    questions = []
    current_chapter = None

    try:
        pdffile_handler = open(pdf_path, "rb")
        pdf_reader_data = PyPDF2.PdfReader(pdffile_handler)
        
        text = ""
        for page_index in range(len(pdf_reader_data.pages)):
            text += pdf_reader_data.pages[page_index].extract_text()

        # Check if text was extracted
        print("\nExtracted text:\n", text[:500])  # Print the first 500 characters to inspect

        # If text is empty or looks wrong, that’s likely the issue
        if not text:
            print("No text extracted from the PDF.")
            return []

        # Regular Expression to capture Chapter Names
        chapter_pattern = re.compile(r"Chapter (\d+):\s*(.*?)(?=\s*Chapter \d+:|$)", re.DOTALL)
        chapters = chapter_pattern.findall(text)

        print("\nchapters [0]:\n", chapters[0])
        print("\nchapters [1]:\n", chapters[1])
        print("\nchapters [2]:\n", chapters[2])
        print("\nchapters [3]:\n", chapters[3])
        for chapter in chapters:
            print("\nchapter :: ", chapter)
            chapter_number, chapter_title = chapter
            print("\nchapter_title :: ", chapter_title)
            current_chapter = chapter_title.split("\n")[0].strip()
            
            # Regular Expression to capture questions and options within a chapter
            question_pattern = re.compile(r"(\d+\.)\s*([^\n]+?)\s*(A\))\s*([^\n]+?)\s*(B\))\s*([^\n]+?)\s*(C\))\s*([^\n]+?)\s*(D\))\s*([^\n]+?)\s*Answer:\s*([A-D])\)", re.DOTALL)
            matches = question_pattern.findall(chapter_title)
            print("\nmatches :: ", matches)

            index = 0
            for match in matches:
                print(f"\nmatch : {match}")
                question_text = match[1].strip()
                options = ",".join(match[2:len(match)])  # Correct the way options are handled
                print(f"\noptions : {options}")
                correct_answer = match[len(match)-1].strip()

                subject_name = "Chemistry"
                temp_questions = {
                    'subject_name': subject_name,
                    'question_text': question_text,
                    'answer_options': options,
                    'correct_answer': correct_answer,
                    'chapter_name': current_chapter
                }
                index += 1
                print(f"index :: {index}")
                questions.append(temp_questions)

    except Exception as e:
        print(f"Error while extracting questions: {e}")
        if not os.path.exists(pdf_path):
            print(f"File is not found in path: {pdf_path}")

    return questions

# Insert questions into the database
def insert_questions_into_db(connection, questions):
    cursor = connection.cursor()
    insert_query = """
    INSERT INTO QUESTIONS (subject_name, question_text, answer_options, correct_answer, chapter_name)
    VALUES (%s, %s, %s, %s, %s);
    """
    
    try:
        for question in questions:
            print(f"Inserting question: {question['question_text']}")
            cursor.execute(insert_query, (
                question['subject_name'],
                question['question_text'],
                question['answer_options'],
                question['correct_answer'],
                question['chapter_name']
            ))
        connection.commit()
        print(f"{len(questions)} questions inserted successfully.")
    except Exception as e:
        print("Error inserting data into database:", e)

def main():
    # Connect to MySQL Database
    connection = connect_to_mysql_database()
    
    if connection:
        create_db_if_not_exists(connection)
        # Create table if it doesn't exist
        create_table_if_not_exists(connection)

    # Extract questions from the PDF
    # 1.Store a PDF file in a folder called “/content” 
    download_link_url = "https://drive.google.com/file/d/1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc/view?usp=drive_link"
    google_download_file_id = download_link_url.split("/")[5]
    # Corrected URL format for downloading the file
    actual_download_link_url = f'https://drive.google.com/uc?id={google_download_file_id}'
    print("actual_download_link_url : ",actual_download_link_url)
    work_folder = "./content"
    
    # Uncomment to download the file
    download_file(work_folder, actual_download_link_url)

    pdf_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    questions = extract_questions_from_pdf(pdf_path)

    if questions:
        # Insert extracted questions into the database
        insert_questions_into_db(connection, questions)

    # Close the database connection
    connection.close()

if __name__ == "__main__":
    main()
# Out:
# Connection to MySQL DB is successful!
# actual_download_link_url :  https://drive.google.com/uc?id=1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc
# Downloading...
# From: https://drive.google.com/uc?id=1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc
# To: /Users/priprabh/Downloads/Priyanka/Learnings & Training/Python/Udemy Python/Python-Coding-Exercises/Python-Coding-Exercises/Assignment/Project5/content/Chemistry Questions.pdf
# 100%|████████████████████████████████████████| 279k/279k [00:00<00:00, 2.42MB/s]
# File downloaded successfully at path :./content/Chemistry Questions.pdf
#
# Extracted text:
#  Chemistry
#
# Chapter 1: Basic concepts of chemistry
#
# 1. What is the SI unit of mass?
# A) Gram (g)
# B) Kilogram (kg)
# C) Pound (lB)
# D) Ounce (oz)
# Answer: B) Kilogram (kg)
# 2. Which of the following is an example of a chemical change?
# A) Melting of ice
# B) Cutting of paper
# C) Rusting of iron
# D) Boiling of water
# Answer: C) Rusting of iron
# 3. What is Avogadro's number?
# A) 6.022×10236.022 \times 10^{23}6.022×1023
# B) 3.14×1033.14 \times 10^33.14×103
# C) 9.81×1029.81 \times
#
# chapters [0]:
#  ('1', "Basic concepts of chemistry  \n \n1. What is the SI unit of mass?  \nA) Gram (g)  \nB) Kilogram (kg)  \nC) Pound (lB)  \nD) Ounce (oz)  \nAnswer: B) Kilogram (kg)  \n2. Which of the following is an example of a chemical change?  \nA) Melting of ice  \nB) Cutting of paper  \nC) Rusting of iron  \nD) Boiling of water  \nAnswer: C) Rusting of iron  \n3. What is Avogadro's number?  \nA) 6.022×10236.022 \\times 10^{23}6.022×1023  \nB) 3.14×1033.14 \\times 10^33.14×103  \nC) 9.81×1029.81 \\times 10^{2}9.81×102  \nD) 1.67×10−241.67 \\times 10^{ -24}1.67×10−24  \nAnswer: A) 6.022×10236.022 \\times 10^{23}6.022×1023  \n4. Which of the following elements has the highest electronegativity?  \nA) Oxygen (O)  \nB) Hydrogen (H)  \nC) Fluorine (F)  \nD) Carbon (C)  \nAnswer: C) Fluorine (F)  \n5. What is the chemical form ula for water?  \nA) CO₂ \nB) H₂O \nC) O₂ \nD) HCl  \nAnswer: B) H ₂O \n6. Which of the following is a homogeneous mixture?  \nA) Sand and water  B) Oil and water  \nC) Salt and water  \nD) Iron filings and sulfur  \nAnswer: C) Salt and water  \n7. What is the molar mass of carbon dioxide (CO ₂)? \nA) 16 g/mol  \nB) 28 g/mol  \nC) 32 g/mol  \nD) 44 g/mol  \nAnswer: D) 44 g/mol  \n8. Which of the following is not a state of matter?  \nA) Solid  \nB) Liquid  \nC) Gas  \nD) Plasma  \nAnswer: D) Plasma  \n9. Which law states that mass is conserved in a chemical reaction?  \nA) Law of Definite Proportions  \nB) Law of Conservation of Mass  \nC) Law of Multiple Proportions  \nD) Law of Constant Composition  \nAnswer: B) Law of Conservation of Mass  \n10. What is the empirical formula of a compound with 40% carbon, 6.67% \nhydrogen, and 53.33% oxygen by mass?  \nA) CH₃O \nB) CH₂O \nC) C₂H₄O₂ \nD) CH₄ \nAnswer: B) CH ₂O")
#
# chapters [1]:
#  ('2', "Structure of Atom  \n \n1. Who proposed the plum pudding model of the atom?  \nA) Niels Bohr  \nB) J.J. Thomson  \nC) Ernest Rutherford  \nD) John Dalton  \nAnswer: B) J.J. Thomson  \n2. What is the charge of a neutron?  \nA) Positive  \nB) Negative  \nC) Neutral  \nD) Depends on the isotope  \nAnswer: C) Neutral  \n3. Which experiment led to the discovery of the nucleus?  \nA) Cathode Ray Experime nt \nB) Gold Foil Experiment  \nC) Oil Drop Experiment  \nD) Photoelectric Effect  \nAnswer: B) Gold Foil Experiment  \n \n4. What is the maximum number of electrons that can occupy a p -orbital?  \nA) 2 \nB) 6 \nC) 10  \nD) 14  \nAnswer: B) 6  \n \n5. Who developed the quantum mechanical model of the atom?  \nA) Werner Heisenberg  \nB) Niels Bohr  \nC) Erwin Schrödinger  \nD) J.J. Thomson  \nAnswer: C) Erwin Schrödinger  \n \n6. What is the principal quantum number primarily associated with?  A) Shape of the orbital  \nB) Energy level of the electron  \nC) Spin of the electron  \nD) Magnetic orientation  \nAnswer: B) Energy level of the electron  \n \n7. In Bohr's model, which property of electrons is quantized?  \nA) Mass  \nB) Charge  \nC) Angular momentum  \nD) Magnetic moment  \nAnswer: C) Angul ar momentum  \n \n8. Which particle was discovered first in the atomic model?  \nA) Electron  \nB) Proton  \nC) Neutron  \nD) Positron  \nAnswer: A) Electron  \n \n9. What is the number of protons in an atom called?  \nA) Atomic mass  \nB) Isotope number  \nC) Atomic number  \nD) Mass number  \nAnswer: C) Atomic number  \n \n10. How many subshells are there in the 3rd energy level?  \nA) 2 \nB) 3 \nC) 4 \nD) 5 \nAnswer: B) 3")
#
# chapters [2]:
#  ('3', 'Classification of elements and periodicity  \n \n1. Who is credited with creating the modern periodic table?  \nA) Dmitri Mendeleev  \nB) Henry Moseley  \nC) Antoine Lavoisier  \nD) J.J. Thomson  \nAnswer: A) Dmitri Mendeleev  \n \n2. What is the basis of classification in the modern periodic table?  \nA) Atomic mass  \nB) Atomic radius  \nC) Atomic number  \nD) Density  \nAnswer: C) Atomic number  \n \n3. Which group of the periodic table contains the noble gases?  \nA) Group 1  \nB) Group 2  \nC) Group 17  \nD) Group 18  \nAnswer: D) Group 18  \n \n4. Elements in the same group of the periodic table generally have similar...  \nA) Atomic numbers  \nB) Chemical properties  \nC) Isotopes  \nD) Mass numbe rs \nAnswer: B) Chemical properties  \n \n5. What term describes the horizontal rows of the periodic table?  \nA) Groups  \nB) Periods  \nC) Clusters  \nD) Series  \nAnswer: B) Periods  \n \n6. The alkali metals are found in which group of the periodic table?  \nA) Group 1  \nB) Group 2  \nC) Group 3  \nD) Group 17  \nAnswer: A) Group 1  \n 7. What characteristic is common to all elements in Group 17 (halogens)?  \nA) They have one valence electron  \nB) They have seven valence electrons  \nC) They are metals  \nD) They are noble gases  \nAnswer: B) They have seven valence electrons  \n \n8. Which of the following elements is a transition metal?  \nA) Sodium  \nB) Magnesium  \nC) Iron  \nD) Oxygen  \nAnswer: C) Iron  \n \n9. What is the general trend for atomic radius as you move down a group in the periodic table?  \nA) It decreases  \nB) It increases  \nC) It remains the same  \nD) It varies unpredictably  \nAnswer: B) It increases  \n \n10. Which of the following elements is located in Period 3 and Group 16?  \nA) Oxygen  \nB) Sulfur  \nC) Chlorine  \nD) Phosphorus  \nAnswer: B) Sulfur  \n \n \n  Chapter  4: Chemical Bonding and Molecular Structure  \n \n1. Which of the following bonds is the strongest?  \nA) Ionic bond  \nB) Covalent bond  \nC) Hydrogen bond  \nD) Van der Waals forces  \nAnswer: A) Ionic bond  \n2. What is the geometry of a molecule with sp² hybridization?  \nA) Linear  \nB) Trigonal planar  \nC) Tetrahedral  \nD) Bent  \nAnswer: B) Trigonal planar  \n3. The bond angle in methane (CH ₄) is: \nA) 109.5°  \nB) 90°  \nC) 120°  \nD) 180°  \nAnswer: A) 109.5°  \n4. Which of the following molecules exhibits resonance?  \nA) CH₄ \nB) O₃ \nC) NH₃ \nD) H₂O \nAnswer: B) O ₃ \n5. Which molecule has the highest dipole moment?  \nA) CO₂ \nB) H₂O \nC) BF₃ \nD) CH₄ \nAnswer: B) H ₂O \n6. What type of bond exists in the oxygen molecule (O ₂)? \nA) Single bond  \nB) Double bond  \nC) Triple bond  D) Ionic bond  \nAnswer: B) Double bond  \n7. Which of  the following molecules is non -polar?  \nA) H₂O \nB) NH₃ \nC) CO₂ \nD) HCl  \nAnswer: C) CO ₂ \n8. In the VSEPR theory, the shape of the SF ₆ molecule is:  \nA) Octahedral  \nB) Trigonal bipyramidal  \nC) Tetrahedral  \nD) Linear  \nAnswer: A) Octahedral  \n9. The bond order of nitrogen m olecule (N ₂) is: \nA) 1 \nB) 2 \nC) 3 \nD) 4 \nAnswer: C) 3  \n10. Which of the following compounds is likely to form hydrogen bonds?  \nA) CH₄ \nB) NH₃ \nC) CCl₄ \nD) CO₂ \nAnswer: B) NH ₃')
#
# chapters [3]:
#  ('5', 'States of Matter  \n1. Which of the following is not a characteristic of a gas?  \nA) Indefinite shape  \nB) Indefinite volume  \nC) High density  \nD) Compressibility  \nAnswer: C) High density  \n2. What happens to the particles in a liquid when it is heated?  \nA) They slow down  \nB) They move farther apart  \nC) They stop moving  \nD) They become denser  \nAnsw er: B) They move farther apart  \n3. Which of the following processes changes a liquid into a gas?  \nA) Condensation  \nB) Sublimation  \nC) Vaporization  \nD) Freezing  \nAnswer: C) Vaporization  \n4. At what temperature does water typically boil at sea level?  \nA) 0°C  \nB) 50°C  \nC) 100°C  \nD) 150°C  \nAnswer: C) 100°C  \n5. Which state of matter has a definite shape and volume?  \nA) Solid  \nB) Liquid  \nC) Gas  \nD) Plasma  \nAnswer: A) Solid  \n6. What is the process called when a solid changes directly into a gas \nwithout passing through the liquid state?  \nA) Melting  \nB) Evaporation  C) Sublimation  \nD) Deposition  \nAnswer: C) Sublimation  \n7. Which of the following statements best describes a liquid?  \nA) Par ticles are tightly packed and vibrate in place  \nB) Particles move freely and have no definite shape or volume  \nC) Particles are close but can move past one another and have a definite volume  \nD) Particles are far apart and fill the entire space available  \nAnsw er: C) Particles are close but can move past one another and have a definite volume  \n8. Which phase change occurs when a gas turns into a liquid?  \nA) Freezing  \nB) Boiling  \nC) Condensation  \nD) Melting  \nAnswer: C) Condensation  \n9. What happens during the process of melting?  \nA) A liquid turns into a gas  \nB) A solid turns into a liquid  \nC) A gas turns into a liquid  \nD) A liquid turns into a solid  \nAnswer: B) A solid turns into a liquid  \n10. Which state of matter is characterized by ionized  particles and is found \nin stars?  \nA) Solid  \nB) Liquid  \nC) Gas  \nD) Plasma  \nAnswer: D) Plasma  \n \n \n \n ')
#
# chapter ::  ('1', "Basic concepts of chemistry  \n \n1. What is the SI unit of mass?  \nA) Gram (g)  \nB) Kilogram (kg)  \nC) Pound (lB)  \nD) Ounce (oz)  \nAnswer: B) Kilogram (kg)  \n2. Which of the following is an example of a chemical change?  \nA) Melting of ice  \nB) Cutting of paper  \nC) Rusting of iron  \nD) Boiling of water  \nAnswer: C) Rusting of iron  \n3. What is Avogadro's number?  \nA) 6.022×10236.022 \\times 10^{23}6.022×1023  \nB) 3.14×1033.14 \\times 10^33.14×103  \nC) 9.81×1029.81 \\times 10^{2}9.81×102  \nD) 1.67×10−241.67 \\times 10^{ -24}1.67×10−24  \nAnswer: A) 6.022×10236.022 \\times 10^{23}6.022×1023  \n4. Which of the following elements has the highest electronegativity?  \nA) Oxygen (O)  \nB) Hydrogen (H)  \nC) Fluorine (F)  \nD) Carbon (C)  \nAnswer: C) Fluorine (F)  \n5. What is the chemical form ula for water?  \nA) CO₂ \nB) H₂O \nC) O₂ \nD) HCl  \nAnswer: B) H ₂O \n6. Which of the following is a homogeneous mixture?  \nA) Sand and water  B) Oil and water  \nC) Salt and water  \nD) Iron filings and sulfur  \nAnswer: C) Salt and water  \n7. What is the molar mass of carbon dioxide (CO ₂)? \nA) 16 g/mol  \nB) 28 g/mol  \nC) 32 g/mol  \nD) 44 g/mol  \nAnswer: D) 44 g/mol  \n8. Which of the following is not a state of matter?  \nA) Solid  \nB) Liquid  \nC) Gas  \nD) Plasma  \nAnswer: D) Plasma  \n9. Which law states that mass is conserved in a chemical reaction?  \nA) Law of Definite Proportions  \nB) Law of Conservation of Mass  \nC) Law of Multiple Proportions  \nD) Law of Constant Composition  \nAnswer: B) Law of Conservation of Mass  \n10. What is the empirical formula of a compound with 40% carbon, 6.67% \nhydrogen, and 53.33% oxygen by mass?  \nA) CH₃O \nB) CH₂O \nC) C₂H₄O₂ \nD) CH₄ \nAnswer: B) CH ₂O")
#
# chapter_title ::  Basic concepts of chemistry
#
# 1. What is the SI unit of mass?
# A) Gram (g)
# B) Kilogram (kg)
# C) Pound (lB)
# D) Ounce (oz)
# Answer: B) Kilogram (kg)
# 2. Which of the following is an example of a chemical change?
# A) Melting of ice
# B) Cutting of paper
# C) Rusting of iron
# D) Boiling of water
# Answer: C) Rusting of iron
# 3. What is Avogadro's number?
# A) 6.022×10236.022 \times 10^{23}6.022×1023
# B) 3.14×1033.14 \times 10^33.14×103
# C) 9.81×1029.81 \times 10^{2}9.81×102
# D) 1.67×10−241.67 \times 10^{ -24}1.67×10−24
# Answer: A) 6.022×10236.022 \times 10^{23}6.022×1023
# 4. Which of the following elements has the highest electronegativity?
# A) Oxygen (O)
# B) Hydrogen (H)
# C) Fluorine (F)
# D) Carbon (C)
# Answer: C) Fluorine (F)
# 5. What is the chemical form ula for water?
# A) CO₂
# B) H₂O
# C) O₂
# D) HCl
# Answer: B) H ₂O
# 6. Which of the following is a homogeneous mixture?
# A) Sand and water  B) Oil and water
# C) Salt and water
# D) Iron filings and sulfur
# Answer: C) Salt and water
# 7. What is the molar mass of carbon dioxide (CO ₂)?
# A) 16 g/mol
# B) 28 g/mol
# C) 32 g/mol
# D) 44 g/mol
# Answer: D) 44 g/mol
# 8. Which of the following is not a state of matter?
# A) Solid
# B) Liquid
# C) Gas
# D) Plasma
# Answer: D) Plasma
# 9. Which law states that mass is conserved in a chemical reaction?
# A) Law of Definite Proportions
# B) Law of Conservation of Mass
# C) Law of Multiple Proportions
# D) Law of Constant Composition
# Answer: B) Law of Conservation of Mass
# 10. What is the empirical formula of a compound with 40% carbon, 6.67%
# hydrogen, and 53.33% oxygen by mass?
# A) CH₃O
# B) CH₂O
# C) C₂H₄O₂
# D) CH₄
# Answer: B) CH ₂O
#
# matches ::  [('1.', 'What is the SI unit of mass?', 'A)', 'Gram (g)', 'B)', 'Kilogram (kg)', 'C)', 'Pound (lB)', 'D)', 'Ounce (oz)', 'B'), ('2.', 'Which of the following is an example of a chemical change?', 'A)', 'Melting of ice', 'B)', 'Cutting of paper', 'C)', 'Rusting of iron', 'D)', 'Boiling of water', 'C'), ('3.', "What is Avogadro's number?", 'A)', '6.022×10236.022 \\times 10^{23}6.022×1023', 'B)', '3.14×1033.14 \\times 10^33.14×103', 'C)', '9.81×1029.81 \\times 10^{2}9.81×102', 'D)', '1.67×10−241.67 \\times 10^{ -24}1.67×10−24', 'A'), ('4.', 'Which of the following elements has the highest electronegativity?', 'A)', 'Oxygen (O)', 'B)', 'Hydrogen (H)', 'C)', 'Fluorine (F)', 'D)', 'Carbon (C)', 'C'), ('5.', 'What is the chemical form ula for water?', 'A)', 'CO₂', 'B)', 'H₂O', 'C)', 'O₂', 'D)', 'HCl', 'B'), ('6.', 'Which of the following is a homogeneous mixture?', 'A)', 'Sand and water', 'B)', 'Oil and water', 'C)', 'Salt and water', 'D)', 'Iron filings and sulfur', 'C'), ('7.', 'What is the molar mass of carbon dioxide (CO ₂)?', 'A)', '16 g/mol', 'B)', '28 g/mol', 'C)', '32 g/mol', 'D)', '44 g/mol', 'D'), ('8.', 'Which of the following is not a state of matter?', 'A)', 'Solid', 'B)', 'Liquid', 'C)', 'Gas', 'D)', 'Plasma', 'D'), ('9.', 'Which law states that mass is conserved in a chemical reaction?', 'A)', 'Law of Definite Proportions', 'B)', 'Law of Conservation of Mass', 'C)', 'Law of Multiple Proportions', 'D)', 'Law of Constant Composition', 'B'), ('53.', '33% oxygen by mass?', 'A)', 'CH₃O', 'B)', 'CH₂O', 'C)', 'C₂H₄O₂', 'D)', 'CH₄', 'B')]
#
# match : ('1.', 'What is the SI unit of mass?', 'A)', 'Gram (g)', 'B)', 'Kilogram (kg)', 'C)', 'Pound (lB)', 'D)', 'Ounce (oz)', 'B')
#
# options : A),Gram (g),B),Kilogram (kg),C),Pound (lB),D),Ounce (oz),B
# index :: 1
#
# match : ('2.', 'Which of the following is an example of a chemical change?', 'A)', 'Melting of ice', 'B)', 'Cutting of paper', 'C)', 'Rusting of iron', 'D)', 'Boiling of water', 'C')
#
# options : A),Melting of ice,B),Cutting of paper,C),Rusting of iron,D),Boiling of water,C
# index :: 2
#
# match : ('3.', "What is Avogadro's number?", 'A)', '6.022×10236.022 \\times 10^{23}6.022×1023', 'B)', '3.14×1033.14 \\times 10^33.14×103', 'C)', '9.81×1029.81 \\times 10^{2}9.81×102', 'D)', '1.67×10−241.67 \\times 10^{ -24}1.67×10−24', 'A')
#
# options : A),6.022×10236.022 \times 10^{23}6.022×1023,B),3.14×1033.14 \times 10^33.14×103,C),9.81×1029.81 \times 10^{2}9.81×102,D),1.67×10−241.67 \times 10^{ -24}1.67×10−24,A
# index :: 3
#
# match : ('4.', 'Which of the following elements has the highest electronegativity?', 'A)', 'Oxygen (O)', 'B)', 'Hydrogen (H)', 'C)', 'Fluorine (F)', 'D)', 'Carbon (C)', 'C')
#
# options : A),Oxygen (O),B),Hydrogen (H),C),Fluorine (F),D),Carbon (C),C
# index :: 4
#
# match : ('5.', 'What is the chemical form ula for water?', 'A)', 'CO₂', 'B)', 'H₂O', 'C)', 'O₂', 'D)', 'HCl', 'B')
#
# options : A),CO₂,B),H₂O,C),O₂,D),HCl,B
# index :: 5
#
# match : ('6.', 'Which of the following is a homogeneous mixture?', 'A)', 'Sand and water', 'B)', 'Oil and water', 'C)', 'Salt and water', 'D)', 'Iron filings and sulfur', 'C')
#
# options : A),Sand and water,B),Oil and water,C),Salt and water,D),Iron filings and sulfur,C
# index :: 6
#
# match : ('7.', 'What is the molar mass of carbon dioxide (CO ₂)?', 'A)', '16 g/mol', 'B)', '28 g/mol', 'C)', '32 g/mol', 'D)', '44 g/mol', 'D')
#
# options : A),16 g/mol,B),28 g/mol,C),32 g/mol,D),44 g/mol,D
# index :: 7
#
# match : ('8.', 'Which of the following is not a state of matter?', 'A)', 'Solid', 'B)', 'Liquid', 'C)', 'Gas', 'D)', 'Plasma', 'D')
#
# options : A),Solid,B),Liquid,C),Gas,D),Plasma,D
# index :: 8
#
# match : ('9.', 'Which law states that mass is conserved in a chemical reaction?', 'A)', 'Law of Definite Proportions', 'B)', 'Law of Conservation of Mass', 'C)', 'Law of Multiple Proportions', 'D)', 'Law of Constant Composition', 'B')
#
# options : A),Law of Definite Proportions,B),Law of Conservation of Mass,C),Law of Multiple Proportions,D),Law of Constant Composition,B
# index :: 9
#
# match : ('53.', '33% oxygen by mass?', 'A)', 'CH₃O', 'B)', 'CH₂O', 'C)', 'C₂H₄O₂', 'D)', 'CH₄', 'B')
#
# options : A),CH₃O,B),CH₂O,C),C₂H₄O₂,D),CH₄,B
# index :: 10
#
# chapter ::  ('2', "Structure of Atom  \n \n1. Who proposed the plum pudding model of the atom?  \nA) Niels Bohr  \nB) J.J. Thomson  \nC) Ernest Rutherford  \nD) John Dalton  \nAnswer: B) J.J. Thomson  \n2. What is the charge of a neutron?  \nA) Positive  \nB) Negative  \nC) Neutral  \nD) Depends on the isotope  \nAnswer: C) Neutral  \n3. Which experiment led to the discovery of the nucleus?  \nA) Cathode Ray Experime nt \nB) Gold Foil Experiment  \nC) Oil Drop Experiment  \nD) Photoelectric Effect  \nAnswer: B) Gold Foil Experiment  \n \n4. What is the maximum number of electrons that can occupy a p -orbital?  \nA) 2 \nB) 6 \nC) 10  \nD) 14  \nAnswer: B) 6  \n \n5. Who developed the quantum mechanical model of the atom?  \nA) Werner Heisenberg  \nB) Niels Bohr  \nC) Erwin Schrödinger  \nD) J.J. Thomson  \nAnswer: C) Erwin Schrödinger  \n \n6. What is the principal quantum number primarily associated with?  A) Shape of the orbital  \nB) Energy level of the electron  \nC) Spin of the electron  \nD) Magnetic orientation  \nAnswer: B) Energy level of the electron  \n \n7. In Bohr's model, which property of electrons is quantized?  \nA) Mass  \nB) Charge  \nC) Angular momentum  \nD) Magnetic moment  \nAnswer: C) Angul ar momentum  \n \n8. Which particle was discovered first in the atomic model?  \nA) Electron  \nB) Proton  \nC) Neutron  \nD) Positron  \nAnswer: A) Electron  \n \n9. What is the number of protons in an atom called?  \nA) Atomic mass  \nB) Isotope number  \nC) Atomic number  \nD) Mass number  \nAnswer: C) Atomic number  \n \n10. How many subshells are there in the 3rd energy level?  \nA) 2 \nB) 3 \nC) 4 \nD) 5 \nAnswer: B) 3")
#
# chapter_title ::  Structure of Atom
#
# 1. Who proposed the plum pudding model of the atom?
# A) Niels Bohr
# B) J.J. Thomson
# C) Ernest Rutherford
# D) John Dalton
# Answer: B) J.J. Thomson
# 2. What is the charge of a neutron?
# A) Positive
# B) Negative
# C) Neutral
# D) Depends on the isotope
# Answer: C) Neutral
# 3. Which experiment led to the discovery of the nucleus?
# A) Cathode Ray Experime nt
# B) Gold Foil Experiment
# C) Oil Drop Experiment
# D) Photoelectric Effect
# Answer: B) Gold Foil Experiment
#
# 4. What is the maximum number of electrons that can occupy a p -orbital?
# A) 2
# B) 6
# C) 10
# D) 14
# Answer: B) 6
#
# 5. Who developed the quantum mechanical model of the atom?
# A) Werner Heisenberg
# B) Niels Bohr
# C) Erwin Schrödinger
# D) J.J. Thomson
# Answer: C) Erwin Schrödinger
#
# 6. What is the principal quantum number primarily associated with?  A) Shape of the orbital
# B) Energy level of the electron
# C) Spin of the electron
# D) Magnetic orientation
# Answer: B) Energy level of the electron
#
# 7. In Bohr's model, which property of electrons is quantized?
# A) Mass
# B) Charge
# C) Angular momentum
# D) Magnetic moment
# Answer: C) Angul ar momentum
#
# 8. Which particle was discovered first in the atomic model?
# A) Electron
# B) Proton
# C) Neutron
# D) Positron
# Answer: A) Electron
#
# 9. What is the number of protons in an atom called?
# A) Atomic mass
# B) Isotope number
# C) Atomic number
# D) Mass number
# Answer: C) Atomic number
#
# 10. How many subshells are there in the 3rd energy level?
# A) 2
# B) 3
# C) 4
# D) 5
# Answer: B) 3
#
# matches ::  [('1.', 'Who proposed the plum pudding model of the atom?', 'A)', 'Niels Bohr', 'B)', 'J.J. Thomson', 'C)', 'Ernest Rutherford', 'D)', 'John Dalton', 'B'), ('2.', 'What is the charge of a neutron?', 'A)', 'Positive', 'B)', 'Negative', 'C)', 'Neutral', 'D)', 'Depends on the isotope', 'C'), ('3.', 'Which experiment led to the discovery of the nucleus?', 'A)', 'Cathode Ray Experime nt', 'B)', 'Gold Foil Experiment', 'C)', 'Oil Drop Experiment', 'D)', 'Photoelectric Effect', 'B'), ('4.', 'What is the maximum number of electrons that can occupy a p -orbital?', 'A)', '2', 'B)', '6', 'C)', '10', 'D)', '14', 'B'), ('5.', 'Who developed the quantum mechanical model of the atom?', 'A)', 'Werner Heisenberg', 'B)', 'Niels Bohr', 'C)', 'Erwin Schrödinger', 'D)', 'J.J. Thomson', 'C'), ('6.', 'What is the principal quantum number primarily associated with?', 'A)', 'Shape of the orbital', 'B)', 'Energy level of the electron', 'C)', 'Spin of the electron', 'D)', 'Magnetic orientation', 'B'), ('7.', "In Bohr's model, which property of electrons is quantized?", 'A)', 'Mass', 'B)', 'Charge', 'C)', 'Angular momentum', 'D)', 'Magnetic moment', 'C'), ('8.', 'Which particle was discovered first in the atomic model?', 'A)', 'Electron', 'B)', 'Proton', 'C)', 'Neutron', 'D)', 'Positron', 'A'), ('9.', 'What is the number of protons in an atom called?', 'A)', 'Atomic mass', 'B)', 'Isotope number', 'C)', 'Atomic number', 'D)', 'Mass number', 'C'), ('10.', 'How many subshells are there in the 3rd energy level?', 'A)', '2', 'B)', '3', 'C)', '4', 'D)', '5', 'B')]
#
# match : ('1.', 'Who proposed the plum pudding model of the atom?', 'A)', 'Niels Bohr', 'B)', 'J.J. Thomson', 'C)', 'Ernest Rutherford', 'D)', 'John Dalton', 'B')
#
# options : A),Niels Bohr,B),J.J. Thomson,C),Ernest Rutherford,D),John Dalton,B
# index :: 1
#
# match : ('2.', 'What is the charge of a neutron?', 'A)', 'Positive', 'B)', 'Negative', 'C)', 'Neutral', 'D)', 'Depends on the isotope', 'C')
#
# options : A),Positive,B),Negative,C),Neutral,D),Depends on the isotope,C
# index :: 2
#
# match : ('3.', 'Which experiment led to the discovery of the nucleus?', 'A)', 'Cathode Ray Experime nt', 'B)', 'Gold Foil Experiment', 'C)', 'Oil Drop Experiment', 'D)', 'Photoelectric Effect', 'B')
#
# options : A),Cathode Ray Experime nt,B),Gold Foil Experiment,C),Oil Drop Experiment,D),Photoelectric Effect,B
# index :: 3
#
# match : ('4.', 'What is the maximum number of electrons that can occupy a p -orbital?', 'A)', '2', 'B)', '6', 'C)', '10', 'D)', '14', 'B')
#
# options : A),2,B),6,C),10,D),14,B
# index :: 4
#
# match : ('5.', 'Who developed the quantum mechanical model of the atom?', 'A)', 'Werner Heisenberg', 'B)', 'Niels Bohr', 'C)', 'Erwin Schrödinger', 'D)', 'J.J. Thomson', 'C')
#
# options : A),Werner Heisenberg,B),Niels Bohr,C),Erwin Schrödinger,D),J.J. Thomson,C
# index :: 5
#
# match : ('6.', 'What is the principal quantum number primarily associated with?', 'A)', 'Shape of the orbital', 'B)', 'Energy level of the electron', 'C)', 'Spin of the electron', 'D)', 'Magnetic orientation', 'B')
#
# options : A),Shape of the orbital,B),Energy level of the electron,C),Spin of the electron,D),Magnetic orientation,B
# index :: 6
#
# match : ('7.', "In Bohr's model, which property of electrons is quantized?", 'A)', 'Mass', 'B)', 'Charge', 'C)', 'Angular momentum', 'D)', 'Magnetic moment', 'C')
#
# options : A),Mass,B),Charge,C),Angular momentum,D),Magnetic moment,C
# index :: 7
#
# match : ('8.', 'Which particle was discovered first in the atomic model?', 'A)', 'Electron', 'B)', 'Proton', 'C)', 'Neutron', 'D)', 'Positron', 'A')
#
# options : A),Electron,B),Proton,C),Neutron,D),Positron,A
# index :: 8
#
# match : ('9.', 'What is the number of protons in an atom called?', 'A)', 'Atomic mass', 'B)', 'Isotope number', 'C)', 'Atomic number', 'D)', 'Mass number', 'C')
#
# options : A),Atomic mass,B),Isotope number,C),Atomic number,D),Mass number,C
# index :: 9
#
# match : ('10.', 'How many subshells are there in the 3rd energy level?', 'A)', '2', 'B)', '3', 'C)', '4', 'D)', '5', 'B')
#
# options : A),2,B),3,C),4,D),5,B
# index :: 10
#
# chapter ::  ('3', 'Classification of elements and periodicity  \n \n1. Who is credited with creating the modern periodic table?  \nA) Dmitri Mendeleev  \nB) Henry Moseley  \nC) Antoine Lavoisier  \nD) J.J. Thomson  \nAnswer: A) Dmitri Mendeleev  \n \n2. What is the basis of classification in the modern periodic table?  \nA) Atomic mass  \nB) Atomic radius  \nC) Atomic number  \nD) Density  \nAnswer: C) Atomic number  \n \n3. Which group of the periodic table contains the noble gases?  \nA) Group 1  \nB) Group 2  \nC) Group 17  \nD) Group 18  \nAnswer: D) Group 18  \n \n4. Elements in the same group of the periodic table generally have similar...  \nA) Atomic numbers  \nB) Chemical properties  \nC) Isotopes  \nD) Mass numbe rs \nAnswer: B) Chemical properties  \n \n5. What term describes the horizontal rows of the periodic table?  \nA) Groups  \nB) Periods  \nC) Clusters  \nD) Series  \nAnswer: B) Periods  \n \n6. The alkali metals are found in which group of the periodic table?  \nA) Group 1  \nB) Group 2  \nC) Group 3  \nD) Group 17  \nAnswer: A) Group 1  \n 7. What characteristic is common to all elements in Group 17 (halogens)?  \nA) They have one valence electron  \nB) They have seven valence electrons  \nC) They are metals  \nD) They are noble gases  \nAnswer: B) They have seven valence electrons  \n \n8. Which of the following elements is a transition metal?  \nA) Sodium  \nB) Magnesium  \nC) Iron  \nD) Oxygen  \nAnswer: C) Iron  \n \n9. What is the general trend for atomic radius as you move down a group in the periodic table?  \nA) It decreases  \nB) It increases  \nC) It remains the same  \nD) It varies unpredictably  \nAnswer: B) It increases  \n \n10. Which of the following elements is located in Period 3 and Group 16?  \nA) Oxygen  \nB) Sulfur  \nC) Chlorine  \nD) Phosphorus  \nAnswer: B) Sulfur  \n \n \n  Chapter  4: Chemical Bonding and Molecular Structure  \n \n1. Which of the following bonds is the strongest?  \nA) Ionic bond  \nB) Covalent bond  \nC) Hydrogen bond  \nD) Van der Waals forces  \nAnswer: A) Ionic bond  \n2. What is the geometry of a molecule with sp² hybridization?  \nA) Linear  \nB) Trigonal planar  \nC) Tetrahedral  \nD) Bent  \nAnswer: B) Trigonal planar  \n3. The bond angle in methane (CH ₄) is: \nA) 109.5°  \nB) 90°  \nC) 120°  \nD) 180°  \nAnswer: A) 109.5°  \n4. Which of the following molecules exhibits resonance?  \nA) CH₄ \nB) O₃ \nC) NH₃ \nD) H₂O \nAnswer: B) O ₃ \n5. Which molecule has the highest dipole moment?  \nA) CO₂ \nB) H₂O \nC) BF₃ \nD) CH₄ \nAnswer: B) H ₂O \n6. What type of bond exists in the oxygen molecule (O ₂)? \nA) Single bond  \nB) Double bond  \nC) Triple bond  D) Ionic bond  \nAnswer: B) Double bond  \n7. Which of  the following molecules is non -polar?  \nA) H₂O \nB) NH₃ \nC) CO₂ \nD) HCl  \nAnswer: C) CO ₂ \n8. In the VSEPR theory, the shape of the SF ₆ molecule is:  \nA) Octahedral  \nB) Trigonal bipyramidal  \nC) Tetrahedral  \nD) Linear  \nAnswer: A) Octahedral  \n9. The bond order of nitrogen m olecule (N ₂) is: \nA) 1 \nB) 2 \nC) 3 \nD) 4 \nAnswer: C) 3  \n10. Which of the following compounds is likely to form hydrogen bonds?  \nA) CH₄ \nB) NH₃ \nC) CCl₄ \nD) CO₂ \nAnswer: B) NH ₃')
#
# chapter_title ::  Classification of elements and periodicity
#
# 1. Who is credited with creating the modern periodic table?
# A) Dmitri Mendeleev
# B) Henry Moseley
# C) Antoine Lavoisier
# D) J.J. Thomson
# Answer: A) Dmitri Mendeleev
#
# 2. What is the basis of classification in the modern periodic table?
# A) Atomic mass
# B) Atomic radius
# C) Atomic number
# D) Density
# Answer: C) Atomic number
#
# 3. Which group of the periodic table contains the noble gases?
# A) Group 1
# B) Group 2
# C) Group 17
# D) Group 18
# Answer: D) Group 18
#
# 4. Elements in the same group of the periodic table generally have similar...
# A) Atomic numbers
# B) Chemical properties
# C) Isotopes
# D) Mass numbe rs
# Answer: B) Chemical properties
#
# 5. What term describes the horizontal rows of the periodic table?
# A) Groups
# B) Periods
# C) Clusters
# D) Series
# Answer: B) Periods
#
# 6. The alkali metals are found in which group of the periodic table?
# A) Group 1
# B) Group 2
# C) Group 3
# D) Group 17
# Answer: A) Group 1
#  7. What characteristic is common to all elements in Group 17 (halogens)?
# A) They have one valence electron
# B) They have seven valence electrons
# C) They are metals
# D) They are noble gases
# Answer: B) They have seven valence electrons
#
# 8. Which of the following elements is a transition metal?
# A) Sodium
# B) Magnesium
# C) Iron
# D) Oxygen
# Answer: C) Iron
#
# 9. What is the general trend for atomic radius as you move down a group in the periodic table?
# A) It decreases
# B) It increases
# C) It remains the same
# D) It varies unpredictably
# Answer: B) It increases
#
# 10. Which of the following elements is located in Period 3 and Group 16?
# A) Oxygen
# B) Sulfur
# C) Chlorine
# D) Phosphorus
# Answer: B) Sulfur
#
#
#   Chapter  4: Chemical Bonding and Molecular Structure
#
# 1. Which of the following bonds is the strongest?
# A) Ionic bond
# B) Covalent bond
# C) Hydrogen bond
# D) Van der Waals forces
# Answer: A) Ionic bond
# 2. What is the geometry of a molecule with sp² hybridization?
# A) Linear
# B) Trigonal planar
# C) Tetrahedral
# D) Bent
# Answer: B) Trigonal planar
# 3. The bond angle in methane (CH ₄) is:
# A) 109.5°
# B) 90°
# C) 120°
# D) 180°
# Answer: A) 109.5°
# 4. Which of the following molecules exhibits resonance?
# A) CH₄
# B) O₃
# C) NH₃
# D) H₂O
# Answer: B) O ₃
# 5. Which molecule has the highest dipole moment?
# A) CO₂
# B) H₂O
# C) BF₃
# D) CH₄
# Answer: B) H ₂O
# 6. What type of bond exists in the oxygen molecule (O ₂)?
# A) Single bond
# B) Double bond
# C) Triple bond  D) Ionic bond
# Answer: B) Double bond
# 7. Which of  the following molecules is non -polar?
# A) H₂O
# B) NH₃
# C) CO₂
# D) HCl
# Answer: C) CO ₂
# 8. In the VSEPR theory, the shape of the SF ₆ molecule is:
# A) Octahedral
# B) Trigonal bipyramidal
# C) Tetrahedral
# D) Linear
# Answer: A) Octahedral
# 9. The bond order of nitrogen m olecule (N ₂) is:
# A) 1
# B) 2
# C) 3
# D) 4
# Answer: C) 3
# 10. Which of the following compounds is likely to form hydrogen bonds?
# A) CH₄
# B) NH₃
# C) CCl₄
# D) CO₂
# Answer: B) NH ₃
#
# matches ::  [('1.', 'Who is credited with creating the modern periodic table?', 'A)', 'Dmitri Mendeleev', 'B)', 'Henry Moseley', 'C)', 'Antoine Lavoisier', 'D)', 'J.J. Thomson', 'A'), ('2.', 'What is the basis of classification in the modern periodic table?', 'A)', 'Atomic mass', 'B)', 'Atomic radius', 'C)', 'Atomic number', 'D)', 'Density', 'C'), ('3.', 'Which group of the periodic table contains the noble gases?', 'A)', 'Group 1', 'B)', 'Group 2', 'C)', 'Group 17', 'D)', 'Group 18', 'D'), ('4.', 'Elements in the same group of the periodic table generally have similar...', 'A)', 'Atomic numbers', 'B)', 'Chemical properties', 'C)', 'Isotopes', 'D)', 'Mass numbe rs', 'B'), ('5.', 'What term describes the horizontal rows of the periodic table?', 'A)', 'Groups', 'B)', 'Periods', 'C)', 'Clusters', 'D)', 'Series', 'B'), ('6.', 'The alkali metals are found in which group of the periodic table?', 'A)', 'Group 1', 'B)', 'Group 2', 'C)', 'Group 3', 'D)', 'Group 17', 'A'), ('7.', 'What characteristic is common to all elements in Group 17 (halogens)?', 'A)', 'They have one valence electron', 'B)', 'They have seven valence electrons', 'C)', 'They are metals', 'D)', 'They are noble gases', 'B'), ('8.', 'Which of the following elements is a transition metal?', 'A)', 'Sodium', 'B)', 'Magnesium', 'C)', 'Iron', 'D)', 'Oxygen', 'C'), ('9.', 'What is the general trend for atomic radius as you move down a group in the periodic table?', 'A)', 'It decreases', 'B)', 'It increases', 'C)', 'It remains the same', 'D)', 'It varies unpredictably', 'B'), ('10.', 'Which of the following elements is located in Period 3 and Group 16?', 'A)', 'Oxygen', 'B)', 'Sulfur', 'C)', 'Chlorine', 'D)', 'Phosphorus', 'B'), ('1.', 'Which of the following bonds is the strongest?', 'A)', 'Ionic bond', 'B)', 'Covalent bond', 'C)', 'Hydrogen bond', 'D)', 'Van der Waals forces', 'A'), ('2.', 'What is the geometry of a molecule with sp² hybridization?', 'A)', 'Linear', 'B)', 'Trigonal planar', 'C)', 'Tetrahedral', 'D)', 'Bent', 'B'), ('3.', 'The bond angle in methane (CH ₄) is:', 'A)', '109.5°', 'B)', '90°', 'C)', '120°', 'D)', '180°', 'A'), ('4.', 'Which of the following molecules exhibits resonance?', 'A)', 'CH₄', 'B)', 'O₃', 'C)', 'NH₃', 'D)', 'H₂O', 'B'), ('5.', 'Which molecule has the highest dipole moment?', 'A)', 'CO₂', 'B)', 'H₂O', 'C)', 'BF₃', 'D)', 'CH₄', 'B'), ('6.', 'What type of bond exists in the oxygen molecule (O ₂)?', 'A)', 'Single bond', 'B)', 'Double bond', 'C)', 'Triple bond', 'D)', 'Ionic bond', 'B'), ('7.', 'Which of  the following molecules is non -polar?', 'A)', 'H₂O', 'B)', 'NH₃', 'C)', 'CO₂', 'D)', 'HCl', 'C'), ('8.', 'In the VSEPR theory, the shape of the SF ₆ molecule is:', 'A)', 'Octahedral', 'B)', 'Trigonal bipyramidal', 'C)', 'Tetrahedral', 'D)', 'Linear', 'A'), ('9.', 'The bond order of nitrogen m olecule (N ₂) is:', 'A)', '1', 'B)', '2', 'C)', '3', 'D)', '4', 'C'), ('10.', 'Which of the following compounds is likely to form hydrogen bonds?', 'A)', 'CH₄', 'B)', 'NH₃', 'C)', 'CCl₄', 'D)', 'CO₂', 'B')]
#
# match : ('1.', 'Who is credited with creating the modern periodic table?', 'A)', 'Dmitri Mendeleev', 'B)', 'Henry Moseley', 'C)', 'Antoine Lavoisier', 'D)', 'J.J. Thomson', 'A')
#
# options : A),Dmitri Mendeleev,B),Henry Moseley,C),Antoine Lavoisier,D),J.J. Thomson,A
# index :: 1
#
# match : ('2.', 'What is the basis of classification in the modern periodic table?', 'A)', 'Atomic mass', 'B)', 'Atomic radius', 'C)', 'Atomic number', 'D)', 'Density', 'C')
#
# options : A),Atomic mass,B),Atomic radius,C),Atomic number,D),Density,C
# index :: 2
#
# match : ('3.', 'Which group of the periodic table contains the noble gases?', 'A)', 'Group 1', 'B)', 'Group 2', 'C)', 'Group 17', 'D)', 'Group 18', 'D')
#
# options : A),Group 1,B),Group 2,C),Group 17,D),Group 18,D
# index :: 3
#
# match : ('4.', 'Elements in the same group of the periodic table generally have similar...', 'A)', 'Atomic numbers', 'B)', 'Chemical properties', 'C)', 'Isotopes', 'D)', 'Mass numbe rs', 'B')
#
# options : A),Atomic numbers,B),Chemical properties,C),Isotopes,D),Mass numbe rs,B
# index :: 4
#
# match : ('5.', 'What term describes the horizontal rows of the periodic table?', 'A)', 'Groups', 'B)', 'Periods', 'C)', 'Clusters', 'D)', 'Series', 'B')
#
# options : A),Groups,B),Periods,C),Clusters,D),Series,B
# index :: 5
#
# match : ('6.', 'The alkali metals are found in which group of the periodic table?', 'A)', 'Group 1', 'B)', 'Group 2', 'C)', 'Group 3', 'D)', 'Group 17', 'A')
#
# options : A),Group 1,B),Group 2,C),Group 3,D),Group 17,A
# index :: 6
#
# match : ('7.', 'What characteristic is common to all elements in Group 17 (halogens)?', 'A)', 'They have one valence electron', 'B)', 'They have seven valence electrons', 'C)', 'They are metals', 'D)', 'They are noble gases', 'B')
#
# options : A),They have one valence electron,B),They have seven valence electrons,C),They are metals,D),They are noble gases,B
# index :: 7
#
# match : ('8.', 'Which of the following elements is a transition metal?', 'A)', 'Sodium', 'B)', 'Magnesium', 'C)', 'Iron', 'D)', 'Oxygen', 'C')
#
# options : A),Sodium,B),Magnesium,C),Iron,D),Oxygen,C
# index :: 8
#
# match : ('9.', 'What is the general trend for atomic radius as you move down a group in the periodic table?', 'A)', 'It decreases', 'B)', 'It increases', 'C)', 'It remains the same', 'D)', 'It varies unpredictably', 'B')
#
# options : A),It decreases,B),It increases,C),It remains the same,D),It varies unpredictably,B
# index :: 9
#
# match : ('10.', 'Which of the following elements is located in Period 3 and Group 16?', 'A)', 'Oxygen', 'B)', 'Sulfur', 'C)', 'Chlorine', 'D)', 'Phosphorus', 'B')
#
# options : A),Oxygen,B),Sulfur,C),Chlorine,D),Phosphorus,B
# index :: 10
#
# match : ('1.', 'Which of the following bonds is the strongest?', 'A)', 'Ionic bond', 'B)', 'Covalent bond', 'C)', 'Hydrogen bond', 'D)', 'Van der Waals forces', 'A')
#
# options : A),Ionic bond,B),Covalent bond,C),Hydrogen bond,D),Van der Waals forces,A
# index :: 11
#
# match : ('2.', 'What is the geometry of a molecule with sp² hybridization?', 'A)', 'Linear', 'B)', 'Trigonal planar', 'C)', 'Tetrahedral', 'D)', 'Bent', 'B')
#
# options : A),Linear,B),Trigonal planar,C),Tetrahedral,D),Bent,B
# index :: 12
#
# match : ('3.', 'The bond angle in methane (CH ₄) is:', 'A)', '109.5°', 'B)', '90°', 'C)', '120°', 'D)', '180°', 'A')
#
# options : A),109.5°,B),90°,C),120°,D),180°,A
# index :: 13
#
# match : ('4.', 'Which of the following molecules exhibits resonance?', 'A)', 'CH₄', 'B)', 'O₃', 'C)', 'NH₃', 'D)', 'H₂O', 'B')
#
# options : A),CH₄,B),O₃,C),NH₃,D),H₂O,B
# index :: 14
#
# match : ('5.', 'Which molecule has the highest dipole moment?', 'A)', 'CO₂', 'B)', 'H₂O', 'C)', 'BF₃', 'D)', 'CH₄', 'B')
#
# options : A),CO₂,B),H₂O,C),BF₃,D),CH₄,B
# index :: 15
#
# match : ('6.', 'What type of bond exists in the oxygen molecule (O ₂)?', 'A)', 'Single bond', 'B)', 'Double bond', 'C)', 'Triple bond', 'D)', 'Ionic bond', 'B')
#
# options : A),Single bond,B),Double bond,C),Triple bond,D),Ionic bond,B
# index :: 16
#
# match : ('7.', 'Which of  the following molecules is non -polar?', 'A)', 'H₂O', 'B)', 'NH₃', 'C)', 'CO₂', 'D)', 'HCl', 'C')
#
# options : A),H₂O,B),NH₃,C),CO₂,D),HCl,C
# index :: 17
#
# match : ('8.', 'In the VSEPR theory, the shape of the SF ₆ molecule is:', 'A)', 'Octahedral', 'B)', 'Trigonal bipyramidal', 'C)', 'Tetrahedral', 'D)', 'Linear', 'A')
#
# options : A),Octahedral,B),Trigonal bipyramidal,C),Tetrahedral,D),Linear,A
# index :: 18
#
# match : ('9.', 'The bond order of nitrogen m olecule (N ₂) is:', 'A)', '1', 'B)', '2', 'C)', '3', 'D)', '4', 'C')
#
# options : A),1,B),2,C),3,D),4,C
# index :: 19
#
# match : ('10.', 'Which of the following compounds is likely to form hydrogen bonds?', 'A)', 'CH₄', 'B)', 'NH₃', 'C)', 'CCl₄', 'D)', 'CO₂', 'B')
#
# options : A),CH₄,B),NH₃,C),CCl₄,D),CO₂,B
# index :: 20
#
# chapter ::  ('5', 'States of Matter  \n1. Which of the following is not a characteristic of a gas?  \nA) Indefinite shape  \nB) Indefinite volume  \nC) High density  \nD) Compressibility  \nAnswer: C) High density  \n2. What happens to the particles in a liquid when it is heated?  \nA) They slow down  \nB) They move farther apart  \nC) They stop moving  \nD) They become denser  \nAnsw er: B) They move farther apart  \n3. Which of the following processes changes a liquid into a gas?  \nA) Condensation  \nB) Sublimation  \nC) Vaporization  \nD) Freezing  \nAnswer: C) Vaporization  \n4. At what temperature does water typically boil at sea level?  \nA) 0°C  \nB) 50°C  \nC) 100°C  \nD) 150°C  \nAnswer: C) 100°C  \n5. Which state of matter has a definite shape and volume?  \nA) Solid  \nB) Liquid  \nC) Gas  \nD) Plasma  \nAnswer: A) Solid  \n6. What is the process called when a solid changes directly into a gas \nwithout passing through the liquid state?  \nA) Melting  \nB) Evaporation  C) Sublimation  \nD) Deposition  \nAnswer: C) Sublimation  \n7. Which of the following statements best describes a liquid?  \nA) Par ticles are tightly packed and vibrate in place  \nB) Particles move freely and have no definite shape or volume  \nC) Particles are close but can move past one another and have a definite volume  \nD) Particles are far apart and fill the entire space available  \nAnsw er: C) Particles are close but can move past one another and have a definite volume  \n8. Which phase change occurs when a gas turns into a liquid?  \nA) Freezing  \nB) Boiling  \nC) Condensation  \nD) Melting  \nAnswer: C) Condensation  \n9. What happens during the process of melting?  \nA) A liquid turns into a gas  \nB) A solid turns into a liquid  \nC) A gas turns into a liquid  \nD) A liquid turns into a solid  \nAnswer: B) A solid turns into a liquid  \n10. Which state of matter is characterized by ionized  particles and is found \nin stars?  \nA) Solid  \nB) Liquid  \nC) Gas  \nD) Plasma  \nAnswer: D) Plasma  \n \n \n \n ')
#
# chapter_title ::  States of Matter
# 1. Which of the following is not a characteristic of a gas?
# A) Indefinite shape
# B) Indefinite volume
# C) High density
# D) Compressibility
# Answer: C) High density
# 2. What happens to the particles in a liquid when it is heated?
# A) They slow down
# B) They move farther apart
# C) They stop moving
# D) They become denser
# Answ er: B) They move farther apart
# 3. Which of the following processes changes a liquid into a gas?
# A) Condensation
# B) Sublimation
# C) Vaporization
# D) Freezing
# Answer: C) Vaporization
# 4. At what temperature does water typically boil at sea level?
# A) 0°C
# B) 50°C
# C) 100°C
# D) 150°C
# Answer: C) 100°C
# 5. Which state of matter has a definite shape and volume?
# A) Solid
# B) Liquid
# C) Gas
# D) Plasma
# Answer: A) Solid
# 6. What is the process called when a solid changes directly into a gas
# without passing through the liquid state?
# A) Melting
# B) Evaporation  C) Sublimation
# D) Deposition
# Answer: C) Sublimation
# 7. Which of the following statements best describes a liquid?
# A) Par ticles are tightly packed and vibrate in place
# B) Particles move freely and have no definite shape or volume
# C) Particles are close but can move past one another and have a definite volume
# D) Particles are far apart and fill the entire space available
# Answ er: C) Particles are close but can move past one another and have a definite volume
# 8. Which phase change occurs when a gas turns into a liquid?
# A) Freezing
# B) Boiling
# C) Condensation
# D) Melting
# Answer: C) Condensation
# 9. What happens during the process of melting?
# A) A liquid turns into a gas
# B) A solid turns into a liquid
# C) A gas turns into a liquid
# D) A liquid turns into a solid
# Answer: B) A solid turns into a liquid
# 10. Which state of matter is characterized by ionized  particles and is found
# in stars?
# A) Solid
# B) Liquid
# C) Gas
# D) Plasma
# Answer: D) Plasma
#
#
#
#
#
# matches ::  [('1.', 'Which of the following is not a characteristic of a gas?', 'A)', 'Indefinite shape', 'B)', 'Indefinite volume', 'C)', 'High density', 'D)', 'Compressibility', 'C'), ('3.', 'Which of the following processes changes a liquid into a gas?', 'A)', 'Condensation', 'B)', 'Sublimation', 'C)', 'Vaporization', 'D)', 'Freezing', 'C'), ('4.', 'At what temperature does water typically boil at sea level?', 'A)', '0°C', 'B)', '50°C', 'C)', '100°C', 'D)', '150°C', 'C'), ('5.', 'Which state of matter has a definite shape and volume?', 'A)', 'Solid', 'B)', 'Liquid', 'C)', 'Gas', 'D)', 'Plasma', 'A'), ('8.', 'Which phase change occurs when a gas turns into a liquid?', 'A)', 'Freezing', 'B)', 'Boiling', 'C)', 'Condensation', 'D)', 'Melting', 'C'), ('9.', 'What happens during the process of melting?', 'A)', 'A liquid turns into a gas', 'B)', 'A solid turns into a liquid', 'C)', 'A gas turns into a liquid', 'D)', 'A liquid turns into a solid', 'B')]
#
# match : ('1.', 'Which of the following is not a characteristic of a gas?', 'A)', 'Indefinite shape', 'B)', 'Indefinite volume', 'C)', 'High density', 'D)', 'Compressibility', 'C')
#
# options : A),Indefinite shape,B),Indefinite volume,C),High density,D),Compressibility,C
# index :: 1
#
# match : ('3.', 'Which of the following processes changes a liquid into a gas?', 'A)', 'Condensation', 'B)', 'Sublimation', 'C)', 'Vaporization', 'D)', 'Freezing', 'C')
#
# options : A),Condensation,B),Sublimation,C),Vaporization,D),Freezing,C
# index :: 2
#
# match : ('4.', 'At what temperature does water typically boil at sea level?', 'A)', '0°C', 'B)', '50°C', 'C)', '100°C', 'D)', '150°C', 'C')
#
# options : A),0°C,B),50°C,C),100°C,D),150°C,C
# index :: 3
#
# match : ('5.', 'Which state of matter has a definite shape and volume?', 'A)', 'Solid', 'B)', 'Liquid', 'C)', 'Gas', 'D)', 'Plasma', 'A')
#
# options : A),Solid,B),Liquid,C),Gas,D),Plasma,A
# index :: 4
#
# match : ('8.', 'Which phase change occurs when a gas turns into a liquid?', 'A)', 'Freezing', 'B)', 'Boiling', 'C)', 'Condensation', 'D)', 'Melting', 'C')
#
# options : A),Freezing,B),Boiling,C),Condensation,D),Melting,C
# index :: 5
#
# match : ('9.', 'What happens during the process of melting?', 'A)', 'A liquid turns into a gas', 'B)', 'A solid turns into a liquid', 'C)', 'A gas turns into a liquid', 'D)', 'A liquid turns into a solid', 'B')
#
# options : A),A liquid turns into a gas,B),A solid turns into a liquid,C),A gas turns into a liquid,D),A liquid turns into a solid,B
# index :: 6
# Inserting question: What is the SI unit of mass?
# Inserting question: Which of the following is an example of a chemical change?
# Inserting question: What is Avogadro's number?
# Inserting question: Which of the following elements has the highest electronegativity?
# Inserting question: What is the chemical form ula for water?
# Inserting question: Which of the following is a homogeneous mixture?
# Inserting question: What is the molar mass of carbon dioxide (CO ₂)?
# Inserting question: Which of the following is not a state of matter?
# Inserting question: Which law states that mass is conserved in a chemical reaction?
# Inserting question: 33% oxygen by mass?
# Inserting question: Who proposed the plum pudding model of the atom?
# Inserting question: What is the charge of a neutron?
# Inserting question: Which experiment led to the discovery of the nucleus?
# Inserting question: What is the maximum number of electrons that can occupy a p -orbital?
# Inserting question: Who developed the quantum mechanical model of the atom?
# Inserting question: What is the principal quantum number primarily associated with?
# Inserting question: In Bohr's model, which property of electrons is quantized?
# Inserting question: Which particle was discovered first in the atomic model?
# Inserting question: What is the number of protons in an atom called?
# Inserting question: How many subshells are there in the 3rd energy level?
# Inserting question: Who is credited with creating the modern periodic table?
# Inserting question: What is the basis of classification in the modern periodic table?
# Inserting question: Which group of the periodic table contains the noble gases?
# Inserting question: Elements in the same group of the periodic table generally have similar...
# Inserting question: What term describes the horizontal rows of the periodic table?
# Inserting question: The alkali metals are found in which group of the periodic table?
# Inserting question: What characteristic is common to all elements in Group 17 (halogens)?
# Inserting question: Which of the following elements is a transition metal?
# Inserting question: What is the general trend for atomic radius as you move down a group in the periodic table?
# Inserting question: Which of the following elements is located in Period 3 and Group 16?
# Inserting question: Which of the following bonds is the strongest?
# Inserting question: What is the geometry of a molecule with sp² hybridization?
# Inserting question: The bond angle in methane (CH ₄) is:
# Inserting question: Which of the following molecules exhibits resonance?
# Inserting question: Which molecule has the highest dipole moment?
# Inserting question: What type of bond exists in the oxygen molecule (O ₂)?
# Inserting question: Which of  the following molecules is non -polar?
# Inserting question: In the VSEPR theory, the shape of the SF ₆ molecule is:
# Inserting question: The bond order of nitrogen m olecule (N ₂) is:
# Inserting question: Which of the following compounds is likely to form hydrogen bonds?
# Inserting question: Which of the following is not a characteristic of a gas?
# Inserting question: Which of the following processes changes a liquid into a gas?
# Inserting question: At what temperature does water typically boil at sea level?
# Inserting question: Which state of matter has a definite shape and volume?
# Inserting question: Which phase change occurs when a gas turns into a liquid?
# Inserting question: What happens during the process of melting?
# 46 questions inserted successfully.

# %%
import mysql.connector

# %%
# Connect to MySQL Database
connection = connect_to_mysql_database()

if connection:
    create_db_if_not_exists(connection)
    # Create table if it doesn't exist
    create_table_if_not_exists(connection)

mycursor = connection.cursor()
mycursor.execute("select * from QUESTIONS where chapter_name='Structure of Atom';")
myresult = mycursor.fetchall()

myresult
# Out:
# Connection to MySQL DB is successful!
# [(11,
#   'Chemistry',
#   'Who proposed the plum pudding model of the atom?',
#   'A),Niels Bohr,B),J.J. Thomson,C),Ernest Rutherford,D),John Dalton,B',
#   'B',
#   'Structure of Atom'),
#  (12,
#   'Chemistry',
#   'What is the charge of a neutron?',
#   'A),Positive,B),Negative,C),Neutral,D),Depends on the isotope,C',
#   'C',
#   'Structure of Atom'),
#  (13,
#   'Chemistry',
#   'Which experiment led to the discovery of the nucleus?',
#   'A),Cathode Ray Experime nt,B),Gold Foil Experiment,C),Oil Drop Experiment,D),Photoelectric Effect,B',
#   'B',
#   'Structure of Atom'),
#  (14,
#   'Chemistry',
#   'What is the maximum number of electrons that can occupy a p -orbital?',
#   'A),2,B),6,C),10,D),14,B',
#   'B',
#   'Structure of Atom'),
#  (15,
#   'Chemistry',
#   'Who developed the quantum mechanical model of the atom?',
#   'A),Werner Heisenberg,B),Niels Bohr,C),Erwin Schrödinger,D),J.J. Thomson,C',
#   'C',
#   'Structure of Atom'),
#  (16,
#   'Chemistry',
#   'What is the principal quantum number primarily associated with?',
#   'A),Shape of the orbital,B),Energy level of the electron,C),Spin of the electron,D),Magnetic orientation,B',
#   'B',
#   'Structure of Atom'),
#  (17,
#   'Chemistry',
#   "In Bohr's model, which property of electrons is quantized?",
#   'A),Mass,B),Charge,C),Angular momentum,D),Magnetic moment,C',
#   'C',
#   'Structure of Atom'),
#  (18,
#   'Chemistry',
#   'Which particle was discovered first in the atomic model?',
#   'A),Electron,B),Proton,C),Neutron,D),Positron,A',
#   'A',
#   'Structure of Atom'),
#  (19,
#   'Chemistry',
#   'What is the number of protons in an atom called?',
#   'A),Atomic mass,B),Isotope number,C),Atomic number,D),Mass number,C',
#   'C',
#   'Structure of Atom'),
#  (20,
#   'Chemistry',
#   'How many subshells are there in the 3rd energy level?',
#   'A),2,B),3,C),4,D),5,B',
#   'B',
#   'Structure of Atom')]

# %%
dict = {}
dict[1]=1
dict[2]=2
dict
# Out:
# {1: 1, 2: 2}

# %%
list=[1,1,2,3,4]
list
# Out:
# [1, 1, 2, 3, 4]

# %%
import os
import PyPDF2
import re

pdf_path = os.path.join("./content", "Chemistry Questions.pdf")

pdffile_handler = open(pdf_path, "rb")
#attach a reader object
pdf_reader_data = PyPDF2.PdfReader(pdffile_handler)

text = ""
for page_index in range(len(pdf_reader_data.pages)):
    text += pdf_reader_data.pages[page_index].extract_text()

# Regular Expression to capture Chapter Names
chapter_pattern = re.compile(r"Chapter (\d+):\s*(.*?)(?=\s*Chapter \d+:|$)", re.DOTALL)
chapters = chapter_pattern.findall(text)

for chapter in chapters:
    chapter_name = chapter[1]
    print(f"chapter_name:{chapter_name.split("\n")[0]}")
# Out:
# chapter_name:Basic concepts of chemistry
# chapter_name:Structure of Atom
# chapter_name:Classification of elements and periodicity
# chapter_name:States of Matter

# %%
dict [1]=1
dict[1]=1
dict[2]=2
dict[2]=3
dict
# Out:
# {1: 1, 2: 3}

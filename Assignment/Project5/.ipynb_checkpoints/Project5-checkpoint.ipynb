# %% [markdown]
# <h1>Project 1</h1>
# Read a pdf file from a folder. Refer to the PDF file Chemistry Questions.pdf
# <br/>
# <h3>Requirements</h3>
# 1.Store a PDF file in a folder called “/content”
# <br/>
# 2.Read PDF file from the folder
# <br/>
# 3.Write the content to a text file called “output.txt”
# <br/>
# 4.Store this file under the “/content” folder
# <br/>
# <h3>Error Handling</h3>
# 1.Take care of case where folder is not available
# <br/>
# 2.Take care of case where PDF file is not present in the content folder
# <br/>
# 3.Take care of case where the output.txt file is not available
# <br/>

# %%
import gdown
import os

# 1.Store a PDF file in a folder called “/content” 
download_link_url = "https://drive.google.com/file/d/1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc/view?usp=drive_link"
google_download_file_id = download_link_url.split("/")[5]
# Corrected URL format for downloading the file
actual_download_link_url = f'https://drive.google.com/uc?id={google_download_file_id}'
work_folder = "./content"

def download_file(actual_download_link_url):
    # Take care of case where folder is not available 
    # Exception Handling
    save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    
    try:
        gdown.download(actual_download_link_url, save_file_path, quiet=False)
        print(f"File downloaded successfully at path :{save_file_path}")
    except:
        if not os.path.exists(work_folder):
            os.makedirs(work_folder)
        gdown.download(actual_download_link_url, save_file_path, quiet=False)
        print(f"File downloaded successfully at path :{save_file_path}")

download_file(actual_download_link_url)

# %%
# 2.Read PDF file from the folder 
import PyPDF2

def readPDFFile(file_path):
    try :
        pdffile_handler = open(file_path, "rb")
        #attach a reader object
        pdf_reader_data = PyPDF2.PdfReader(pdffile_handler)
    except:
        if not os.path.exists(file_path):
            print(f"File is not found in path : {file_path}")

save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
readPDFFile(save_file_path)

# %%
# 3.Write the content to a text file called “output.txt” 
output_file_name = "output.txt"

output_file_handler = open(output_file_name, "w+")

for page_index in range(len(pdf_reader_data.pages)):
    content = pdf_reader_data.pages[page_index].extract_text()
    output_file_handler.write(content)

output_file_handler.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 6
#       2 output_file_name = "output.txt"
#       4 output_file_handler = open(output_file_name, "w+")
# ----> 6 for page_index in range(len(pdf_reader_data.pages)):
#       7     content = pdf_reader_data.pages[page_index].extract_text()
#       8     output_file_handler.write(content)
#
# NameError: name 'pdf_reader_data' is not defined

# %%
# 4.Store this file under the “/content” folder 
import shutil

save_output_txt_directory = "./content"

output_file_name = "output.txt"

save_output_txt_file_path = os.path.join(save_output_txt_directory, output_file_name)

try :
    #If output.txt file exists we need to save it under /content folder
    shutil.copyfile(output_file_name, save_output_txt_file_path)
except:
    # 3.Take care of case where the output.txt file is not available 
    if not os.path.exists(output_file_name):
        print(f"output.txt file is not found in path : {os.getcwd()}")

# %%
import gdown
import os
import PyPDF2
import shutil

def download_file(actual_download_link_url):
    # Take care of case where folder is not available 
    # Exception Handling
    save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    
    try:
        gdown.download(actual_download_link_url, save_file_path, quiet=False)
        print(f"File downloaded successfully at path :{save_file_path}")
    except:
        if not os.path.exists(work_folder):
            os.makedirs(work_folder)
        gdown.download(actual_download_link_url, save_file_path, quiet=False)
        print(f"File downloaded successfully at path :{save_file_path}")

def main():
    # 1.Store a PDF file in a folder called “/content” 
    download_link_url = "https://drive.google.com/file/d/1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc/view?usp=drive_link"
    google_download_file_id = download_link_url.split("/")[5]
    # Corrected URL format for downloading the file
    actual_download_link_url = f'https://drive.google.com/uc?id={google_download_file_id}'
    work_folder = "./content"
    
    download_file(actual_download_link_url)

    # 2.Read PDF file from the folder 
    save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    try :
        pdffile_handler = open(save_file_path, "rb")
        #attach a reader object
        pdf_reader_data = PyPDF2.PdfReader(pdffile_handler)
    except:
        if not os.path.exists(save_file_path):
            print(f"File is not found in path : {save_file_path}")

    # 3.Write the content to a text file called “output.txt” 
    output_file_name = "output.txt"
    output_file_handler = open(output_file_name, "w+")
    
    for page_index in range(len(pdf_reader_data.pages)):
        content = pdf_reader_data.pages[page_index].extract_text()
        output_file_handler.write(content)
    
    output_file_handler.close()

    # 4.Store this file under the “/content” folder 
    save_output_txt_directory = "./content"    
    save_output_txt_file_path = os.path.join(save_output_txt_directory, output_file_name)
    
    try :
        #If output.txt file exists we need to save it under /content folder
        shutil.copyfile(output_file_name, save_output_txt_file_path)
    except:
        # 3.Take care of case where the output.txt file is not available 
        if not os.path.exists(output_file_name):
            print(f"output.txt file is not found in path : {os.getcwd()}")

if __name__ == "__main__":
    main()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc
# To: /Users/priprabh/Downloads/Priyanka/Learnings & Training/Python/Udemy Python/Python-Coding-Exercises/Python-Coding-Exercises/Assignment/Project5/content/Chemistry Questions.pdf
# 100%|████████████████████████████████████████| 279k/279k [00:00<00:00, 4.56MB/s]
# File downloaded successfully at path :./content/Chemistry Questions.pdf

# %% [markdown]
# <h1>Project 3</h1>
# Read content from a particular page<br/>
# <h3>Requirements</h3>
# Update project 1 and update the reading of content <br/>
# Take a page number as an input from command prompt<br/>
# Read content of the page number provided and write to the output file<br/>
# <h3>Error Handling</h3>
# Take care of case where folder is not available<br/>
# Take care of case where PDF file is not present in a sub-folder<br/>
# Take care of case where the output.txt file is not available in a sub-folder<br/>

# %%
valid_range_list = list(map(str, range(1,11)))

page_number = input("Enter a number in range 1-10:")
while not page_number.isdigit() or page_number not in valid_range_list:
    page_number = input("Enter a number in range 1-10:")
    if page_number.isdigit() and page_number in valid_range_list:
        break
    else:
        continue

print(page_number)
# Out:
# Enter a number in range 1-10: 1
# 1

# %%
import gdown
import os
import PyPDF2
import shutil

def download_file(actual_download_link_url):
    # Take care of case where folder is not available 
    # Exception Handling
    save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    
    try:
        gdown.download(actual_download_link_url, save_file_path, quiet=False)
        print(f"File downloaded successfully at path :{save_file_path}")
    except:
        if not os.path.exists(work_folder):
            os.makedirs(work_folder)
        gdown.download(actual_download_link_url, save_file_path, quiet=False)
        print(f"File downloaded successfully at path :{save_file_path}")

def main():
    # 1.Store a PDF file in a folder called “/content” 
    download_link_url = "https://drive.google.com/file/d/1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc/view?usp=drive_link"
    google_download_file_id = download_link_url.split("/")[5]
    # Corrected URL format for downloading the file
    actual_download_link_url = f'https://drive.google.com/uc?id={google_download_file_id}'
    work_folder = "./content"
    
    download_file(actual_download_link_url)

    # 2.Read PDF file from the folder 
    save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    try :
        pdffile_handler = open(save_file_path, "rb")
        #attach a reader object
        pdf_reader_data = PyPDF2.PdfReader(pdffile_handler)
    except:
        if not os.path.exists(save_file_path):
            print(f"File is not found in path : {save_file_path}")

    # 3.Write the content to a text file called “output.txt” 
    output_file_name = "output.txt"
    output_file_handler = open(output_file_name, "w+")
    
    # for page_index in range(len(pdf_reader_data.pages)):
    #     content = pdf_reader_data.pages[page_index].extract_text()
    #     output_file_handler.write(content)

    # Take a page number as an input from command prompt
    valid_page_numbers_range_list = list(map(str, range(1,11)))

    page_number = input("Enter a number in range 1-10:")
    while not page_number.isdigit() or page_number not in valid_range_list:
        page_number = input("Enter a number in range 1-10:")
        if page_number.isdigit() and page_number in valid_range_list:
            break
        else:
            continue

    # Read content of the page number provided and write to the output file
    page_no = int(page_number) - 1 #since page no start from 0 index
    content = pdf_reader_data.pages[page_no].extract_text()
    print(pdf_reader_data.pages[page_no].extract_text())
    output_file_handler.write(content)
    output_file_handler.close()

    # 4.Store this file under the “/content” folder 
    save_output_txt_directory = "./content"    
    save_output_txt_file_path = os.path.join(save_output_txt_directory, output_file_name)
    
    try :
        #If output.txt file exists we need to save it under /content folder
        shutil.copyfile(output_file_name, save_output_txt_file_path)
    except:
        # 3.Take care of case where the output.txt file is not available 
        if not os.path.exists(output_file_name):
            print(f"output.txt file is not found in path : {os.getcwd()}")

if __name__ == "__main__":
    main()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc
# To: /Users/priprabh/Downloads/Priyanka/Learnings & Training/Python/Udemy Python/Python-Coding-Exercises/Python-Coding-Exercises/Assignment/Project5/content/Chemistry Questions.pdf
# 100%|████████████████████████████████████████| 279k/279k [00:00<00:00, 2.40MB/s]
# File downloaded successfully at path :./content/Chemistry Questions.pdf
# Enter a number in range 1-10: 1
# Chemistry
#
# Chapter 1: Basic concepts of chemistry
#
# 1. What is the SI unit of mass?
# A) Gram (g)
# B) Kilogram (kg)
# C) Pound (lB)
# D) Ounce (oz)
# Answer: B) Kilogram (kg)
# 2. Which of the following is an example of a chemical change?
# A) Melting of ice
# B) Cutting of paper
# C) Rusting of iron
# D) Boiling of water
# Answer: C) Rusting of iron
# 3. What is Avogadro's number?
# A) 6.022×10236.022 \times 10^{23}6.022×1023
# B) 3.14×1033.14 \times 10^33.14×103
# C) 9.81×1029.81 \times 10^{2}9.81×102
# D) 1.67×10−241.67 \times 10^{ -24}1.67×10−24
# Answer: A) 6.022×10236.022 \times 10^{23}6.022×1023
# 4. Which of the following elements has the highest electronegativity?
# A) Oxygen (O)
# B) Hydrogen (H)
# C) Fluorine (F)
# D) Carbon (C)
# Answer: C) Fluorine (F)
# 5. What is the chemical form ula for water?
# A) CO₂
# B) H₂O
# C) O₂
# D) HCl
# Answer: B) H ₂O
# 6. Which of the following is a homogeneous mixture?
# A) Sand and water

# %% [markdown]
# <h1>Project 4</h1>
# Read regular expression from a config file and extract content<br/>
# <h3>Requirements</h3>
# Update project 3<br/>
# Add support for a configuration file <br/>
# In the configuration file set a config with key “regex” and value some regular expression that will match a part of the content in the PDF<br/>
# Update code to extract only the content matching the regular expression<br/>
# Write to the output file<br/>
# <h3>Error Handling</h3>
# Take care of case where folder is not available<br/>
# Take care of case where PDF file is not present in a sub-folder<br/>
# Take care of case where the output.txt file is not available in a sub-folder<br/>
# Take care of case where no configuration file is available<br/>
# Take care of the case where configuration file does not have the regular expression<br/>

# %%
import re

#To fetch answer values
pattern = r"Chapter \d+:.*[^\S\r\n]"

with open("output.txt", "r") as f:
    content = f.read()
    f.seek(0)

list1 = re.findall(pattern, content)
list1[0].split(":")[1].strip()
# Out:
# 'Basic concepts of chemistry'

# %%
import re

#To fetch questions 
pattern = r"\d+\.\s[A-Za-z0-9?.! ]*"

with open("output.txt", "r") as f:
    content = f.read()
    f.seek(0)

print(content)

re.findall(pattern, content)
# Out:
# Chemistry
#
# Chapter 1: Basic concepts of chemistry
#
# 1. What is the SI unit of mass?
# A) Gram (g)
# B) Kilogram (kg)
# C) Pound (lB)
# D) Ounce (oz)
# Answer: B) Kilogram (kg)
# 2. Which of the following is an example of a chemical change?
# A) Melting of ice
# B) Cutting of paper
# C) Rusting of iron
# D) Boiling of water
# Answer: C) Rusting of iron
# 3. What is Avogadro's number?
# A) 6.022×10236.022 \times 10^{23}6.022×1023
# B) 3.14×1033.14 \times 10^33.14×103
# C) 9.81×1029.81 \times 10^{2}9.81×102
# D) 1.67×10−241.67 \times 10^{ -24}1.67×10−24
# Answer: A) 6.022×10236.022 \times 10^{23}6.022×1023
# 4. Which of the following elements has the highest electronegativity?
# A) Oxygen (O)
# B) Hydrogen (H)
# C) Fluorine (F)
# D) Carbon (C)
# Answer: C) Fluorine (F)
# 5. What is the chemical form ula for water?
# A) CO₂
# B) H₂O
# C) O₂
# D) HCl
# Answer: B) H ₂O
# 6. Which of the following is a homogeneous mixture?
# A) Sand and water
# ['1. What is the SI unit of mass?  ',
#  '2. Which of the following is an example of a chemical change?  ',
#  '3. What is Avogadro',
#  '4. Which of the following elements has the highest electronegativity?  ',
#  '5. What is the chemical form ula for water?  ',
#  '6. Which of the following is a homogeneous mixture?  ']

# %%
#Add support for a configuration file
# In the configuration file set a config with key “regex” and value some regular expression that will match a part of the content in the PDF
# %%writefile config.xml
<config>
    <regex>
        <questions>"\d+\.\s[A-Za-z0-9?.! ]*"</questions>
        <answers>"Answer: *[A-Z)]*\s[A-Za-z]*"</answers>
    </regex>
</config>

# %%
# take page number input and see if it matches with regex then only matched patterns add to output.txt
# Update code to extract only the content matching the regular expression

# %%
import re

#To fetch questions 
pattern = r"\d+\.\s[A-Za-z0-9?.! ]*"

with open("output.txt", "r") as f:
    content = f.read()
    f.seek(0)
re.findall(pattern, content)
# Out:
# ['1. What is the SI unit of mass?  ',
#  '2. Which of the following is an example of a chemical change?  ',
#  '3. What is Avogadro',
#  '4. Which of the following elements has the highest electronegativity?  ',
#  '5. What is the chemical form ula for water?  ',
#  '6. Which of the following is a homogeneous mixture?  ']

# %%
import xml.etree.ElementTree as ET
import os

def parseConfigFile(config_file):
    tree = ET.parse(config_file)
    # Take care of the case where configuration file does not have the regular expression
    try:
        root = tree.getroot()
        question_pattern_str = ""
        answers_pattern_str  = ""
        for temp in root.findall('.//regex'):
            question_pattern_str = temp.find('.//questions').text
            answers_pattern_str = temp.find('.//answers').text
    
        print(question_pattern_str)
        print(answers_pattern_str)
    except:
        print("No Regex Expression given in file")
    return question_pattern_str, answers_pattern_str

# Take care of case where no configuration file is available
try:
    parseConfigFile("./config.xml")
except:
    if not os.path.exists("./config.xml"):
        print("Config File is not found in directory")
# Out:
# "\d+\.\s[A-Za-z0-9?.! ]*"
# "Answer: *[A-Z)]*\s[A-Za-z]*"

# %%
import gdown
import os
import PyPDF2
import shutil
import xml.etree.ElementTree as ET
import os

def parseConfigFile(config_file):
    tree = ET.parse(config_file)
    # Take care of the case where configuration file does not have the regular expression
    try:
        root = tree.getroot()
        question_pattern_str = ""
        answers_pattern_str  = ""
        for temp in root.findall('.//regex'):
            question_pattern_str = temp.find('.//questions').text
            answers_pattern_str = temp.find('.//answers').text
    
        print(question_pattern_str)
        print(answers_pattern_str)
    except:
        print("No Regex Expression given in file")
    return question_pattern_str.replace('"', ''), answers_pattern_str.replace('"', '')

def download_file(work_folder, actual_download_link_url):
    # Take care of case where folder is not available 
    # Exception Handling
    save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    
    try:
        gdown.download(actual_download_link_url, save_file_path, quiet=False)
        print(f"File downloaded successfully at path :{save_file_path}")
    except:
        if not os.path.exists(work_folder):
            os.makedirs(work_folder)
        gdown.download(actual_download_link_url, save_file_path, quiet=True)
        print(f"File downloaded successfully at path :{save_file_path}")

def main():
    # 1.Store a PDF file in a folder called “/content” 
    download_link_url = "https://drive.google.com/file/d/1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc/view?usp=drive_link"
    google_download_file_id = download_link_url.split("/")[5]
    # Corrected URL format for downloading the file
    actual_download_link_url = f'https://drive.google.com/uc?id={google_download_file_id}'
    work_folder = "./content"
    
    download_file(work_folder, actual_download_link_url)

    # 2.Read PDF file from the folder 
    save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    try :
        pdffile_handler = open(save_file_path, "rb")
        #attach a reader object
        pdf_reader_data = PyPDF2.PdfReader(pdffile_handler)
    except:
        if not os.path.exists(save_file_path):
            print(f"File is not found in path : {save_file_path}")

    # 3.Write the content to a text file called “output.txt” 
    output_file_name = "output.txt"
    output_file_handler = open(output_file_name, "w+")
    
    # for page_index in range(len(pdf_reader_data.pages)):
    #     content = pdf_reader_data.pages[page_index].extract_text()
    #     output_file_handler.write(content)

    # Take a page number as an input from command prompt
    valid_page_numbers_range_list = list(map(str, range(1,11)))

    page_number = input("Enter a number in range 1-10:")
    while not page_number.isdigit() or page_number not in valid_page_numbers_range_list:
        page_number = input("Enter a number in range 1-10:")
        if page_number.isdigit() and page_number in valid_page_numbers_range_list:
            break
        else:
            continue

    # Read content of the page number provided and write to the output file
    # Take care of case where no configuration file is available
    page_no = int(page_number) - 1 #since page no start from 0 index
    content = pdf_reader_data.pages[page_no].extract_text()
    print(pdf_reader_data.pages[page_no].extract_text())
    # Update code to extract only the content matching the regular expression
    matched_ques_list = []
    matched_ans_list = []
    try:
        questions_regex_pattern, answers_regex_pattern = parseConfigFile("./config.xml")
        if(questions_regex_pattern!=""):
            matched_ques_list = re.findall(questions_regex_pattern, content)
        if(answers_regex_pattern!=""):
            matched_ans_list = re.findall(answers_regex_pattern, content)
        print(f"matched_ques_list : {matched_ques_list}")
        print(f"matched_ans_list : {matched_ans_list}")
    except:
        if not os.path.exists("./config.xml"):
            print("Config File is not found in directory")

    output_str_content = "\n".join(matched_ques_list)
    print(f"output_str_content {output_str_content}")
    output_file_handler.write(output_str_content)
    output_file_handler.close()

    # 4.Store this file under the “/content” folder 
    save_output_txt_directory = "./content"    
    save_output_txt_file_path = os.path.join(save_output_txt_directory, output_file_name)
    
    try :
        #If output.txt file exists we need to save it under /content folder
        shutil.copyfile(output_file_name, save_output_txt_file_path)
    except:
        # 3.Take care of case where the output.txt file is not available 
        if not os.path.exists(output_file_name):
            print(f"output.txt file is not found in path : {os.getcwd()}")

if __name__ == "__main__":
    main()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc
# To: /Users/priprabh/Downloads/Priyanka/Learnings & Training/Python/Udemy Python/Python-Coding-Exercises/Python-Coding-Exercises/Assignment/Project5/content/Chemistry Questions.pdf
# 100%|████████████████████████████████████████| 279k/279k [00:00<00:00, 2.10MB/s]
# File downloaded successfully at path :./content/Chemistry Questions.pdf
# Enter a number in range 1-10: 1
# Chemistry
#
# Chapter 1: Basic concepts of chemistry
#
# 1. What is the SI unit of mass?
# A) Gram (g)
# B) Kilogram (kg)
# C) Pound (lB)
# D) Ounce (oz)
# Answer: B) Kilogram (kg)
# 2. Which of the following is an example of a chemical change?
# A) Melting of ice
# B) Cutting of paper
# C) Rusting of iron
# D) Boiling of water
# Answer: C) Rusting of iron
# 3. What is Avogadro's number?
# A) 6.022×10236.022 \times 10^{23}6.022×1023
# B) 3.14×1033.14 \times 10^33.14×103
# C) 9.81×1029.81 \times 10^{2}9.81×102
# D) 1.67×10−241.67 \times 10^{ -24}1.67×10−24
# Answer: A) 6.022×10236.022 \times 10^{23}6.022×1023
# 4. Which of the following elements has the highest electronegativity?
# A) Oxygen (O)
# B) Hydrogen (H)
# C) Fluorine (F)
# D) Carbon (C)
# Answer: C) Fluorine (F)
# 5. What is the chemical form ula for water?
# A) CO₂
# B) H₂O
# C) O₂
# D) HCl
# Answer: B) H ₂O
# 6. Which of the following is a homogeneous mixture?
# A) Sand and water
# "\d+\.\s[A-Za-z0-9?.! ]*"
# "Answer: *[A-Z)]*\s[A-Za-z]*"
# matched_ques_list : ['1. What is the SI unit of mass?  ', '2. Which of the following is an example of a chemical change?  ', '3. What is Avogadro', '4. Which of the following elements has the highest electronegativity?  ', '5. What is the chemical form ula for water?  ', '6. Which of the following is a homogeneous mixture?  ']
# matched_ans_list : ['Answer: B) Kilogram', 'Answer: C) Rusting', 'Answer: A) ', 'Answer: C) Fluorine', 'Answer: B) H']
# output_str_content 1. What is the SI unit of mass?
# 2. Which of the following is an example of a chemical change?
# 3. What is Avogadro
# 4. Which of the following elements has the highest electronegativity?
# 5. What is the chemical form ula for water?
# 6. Which of the following is a homogeneous mixture?

# %%
a_list=['aaa','bbb','ccc']
b_list = [1,2,4]
zipped_output = zip(a_list, b_list)
zipped_output_str_content = "".join([f"\n{x}\n{y}" for x,y in zipped_output])
print(f"zipped_output_str_content {zipped_output_str_content}")
# Out:
# zipped_output_str_content
# aaa
# 1
# bbb
# 2
# ccc
# 4

# %% [markdown]
# <h1>Project 5</h1>
# Store extracted questions in mysql<br/>
# <h3>Requirements</h3>
# Update project 4 and add support for database<br/>
# Create a database to store the following<br/>
# Subject Name<br/>
# Question Text<br/>
# Answer options<br/>
# Chapter name<br/>
# Load a PDF containing questions<br/>
# Extract each question as per a regular expression<br/>
# Store each question in the database<br/>
# <h3>Error Handling</h3>
# Take care of case where database is not available<br/>
# Take care of case where table is not available<br/>
# Take care of any error handling in DB operations<br/>

# %%
# MySQL installation steps 
# https://medium.com/@rodolfovmartins/how-to-install-mysql-on-mac-959df86a5319

#https://www.w3schools.com/python/python_mysql_create_table.asp
#pip install mysql-connector-python

# %%
#Return a list of your system's databases:

#Check if DB exists
import mysql.connector

mydb = mysql.connector.connect(host="localhost",
  user="priya",
  password="priya"
)

mycursor = mydb.cursor()
mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)

# %%
#check tables in Database
import mysql.connector

mydb = mysql.connector.connect(host="localhost",
  user="priya",
  password="priya",
  database="mydatabase"
)

mycursor = mydb.cursor()
mycursor.execute("select * from subject")

myresult = mycursor.fetchall()

for x in myresult:
  print(f"x:{x}")

# %%
#Create Database
import mysql.connector

mydb = mysql.connector.connect(host="localhost",
  user="priya",
  password="priya"
)

mycursor = mydb.cursor()
mycursor.execute("CREATE DATABASE mydatabase")

# %%
#Create Table in DB
#Create a database to store the following
#Subject Name
#Question Text
#Answer options
#Chapter name

import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="priya",
  password="priya",
  database="mydatabase"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE subject (name VARCHAR(255), question_text VARCHAR(255), ans_options VARCHAR(255), chapter_name VARCHAR(255))")

# %%
#Load a PDF containing questions
#Extract each question as per a regular expression
#Store each question in the database

import gdown
import os
import PyPDF2
import shutil
import xml.etree.ElementTree as ET
import os
import mysql.connector

def parseConfigFile(config_file):
    tree = ET.parse(config_file)
    # Take care of the case where configuration file does not have the regular expression
    try:
        root = tree.getroot()
        question_pattern_str = ""
        answers_pattern_str  = ""
        chapter_pattern_str = ""
        for temp in root.findall('.//regex'):
            question_pattern_str = temp.find('.//questions').text
            answers_pattern_str = temp.find('.//answers').text
            chapter_pattern_str = temp.find('.//chapter').text
    except:
        print("No Regex Expression given in file")
    return question_pattern_str.replace('"', ''), answers_pattern_str.replace('"', ''), chapter_pattern_str.replace('"', '')

def download_file(work_folder, actual_download_link_url):
    # Take care of case where folder is not available 
    # Exception Handling
    save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    
    try:
        gdown.download(actual_download_link_url, save_file_path, quiet=False)
        print(f"File downloaded successfully at path :{save_file_path}")
    except:
        if not os.path.exists(work_folder):
            os.makedirs(work_folder)
        gdown.download(actual_download_link_url, save_file_path, quiet=True)
        print(f"File downloaded successfully at path :{save_file_path}")

#check tables in Database
def checkDBIfExists(hostname, username, password, dbname):
    try:
        mydb = mysql.connector.connect(host=hostname,
          user=username,
          password=password,
          database=dbname
        )
        mycursor = mydb.cursor()
    except Exception as e: 
        print(f"Exception encountered : {e.args[1]}")
    return mycursor

#Take care of any error handling in DB operations
def insertSubjectRecordToDB(ques_list, ans_list, chapter_list, mycursor):
    try:
        sql = "INSERT INTO SUBJECT (name, question_text, ans_options, chapter_name) VALUES (%s, %s, %s, %s)"
        val = ()
        val[0] = "Chemistry"
        for i in len(ques_list):
            val[1] = ques_list[i]
            val[2] = ans_list[i]
        val = ("John", "Highway 21")
        mycursor.execute(sql, val)
        mydb.commit()
        print(mycursor.rowcount, "record inserted.")
    except Exception as e: 
        print("Database operations failed!")
        e.with_traceback()

def main():
    # 1.Store a PDF file in a folder called “/content” 
    download_link_url = "https://drive.google.com/file/d/1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc/view?usp=drive_link"
    google_download_file_id = download_link_url.split("/")[5]
    # Corrected URL format for downloading the file
    actual_download_link_url = f'https://drive.google.com/uc?id={google_download_file_id}'
    work_folder = "./content"
    
    download_file(work_folder, actual_download_link_url)

    # 2.Read PDF file from the folder 
    save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    try :
        pdffile_handler = open(save_file_path, "rb")
        #attach a reader object
        pdf_reader_data = PyPDF2.PdfReader(pdffile_handler)
    except:
        if not os.path.exists(save_file_path):
            print(f"File is not found in path : {save_file_path}")

    # 3.Write the content to a text file called “output.txt” 
    output_file_name = "output.txt"
    output_file_handler = open(output_file_name, "w+")

    # Update code to extract only the content matching the regular expression
    matched_ques_list = []
    matched_ans_list = []
    matched_chapter_list = []
    
    for page_index in range(len(pdf_reader_data.pages)):
        content = pdf_reader_data.pages[page_index].extract_text()
        
        try:
            questions_regex_pattern_list, answers_regex_pattern_list, chapter_regex_pattern_list = parseConfigFile("./config.xml")
            if(questions_regex_pattern_list!=""):
                matched_ques_list.extend(re.findall(questions_regex_pattern_list, content))
            if(answers_regex_pattern_list!=""):
                matched_ans_list.extend(re.findall(answers_regex_pattern_list, content))
            if(chapter_regex_pattern_list!=""):
                matched_chapter_list.extend(re.findall(chapter_regex_pattern_list, content))
        except:
            if not os.path.exists("./config.xml"):
                print("Config File is not found in directory")
        print(f"\nmatched_ques_list : {matched_ques_list}")
        print(f"\nmatched_ans_list : {matched_ans_list}")
        print(f"\nmatched_chapter_list : {matched_chapter_list}")

        
    output_file_handler.close()

    # print(f"\nmatched_ques_list : {matched_ques_list}")
    # print(f"\nmatched_ans_list : {matched_ans_list}")
    # print(f"\nmatched_chapter_list : {matched_chapter_list}")

    #Error Handling
    #Take care of case where database is not available
    #Take care of case where table is not available
    mycursor = checkDBIfExists("localhost", "priya", "priya", "mydatabase")   
    #Take care of any error handling in DB operations
    #insertSubjectRecordToDB(matched_ques_list, matched_ans_list, matched_chapter_list, mycursor)
            
if __name__ == "__main__":
    main()

# %%
#Project 5 implementation

import gdown
import os
import PyPDF2
import os
import mysql.connector

def download_file(work_folder, actual_download_link_url):
    # Take care of case where folder is not available 
    # Exception Handling
    save_file_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    
    try:
        gdown.download(actual_download_link_url, save_file_path, quiet=False)
        print(f"File downloaded successfully at path :{save_file_path}")
    except:
        if not os.path.exists(work_folder):
            os.makedirs(work_folder)
        gdown.download(actual_download_link_url, save_file_path, quiet=True)
        print(f"File downloaded successfully at path :{save_file_path}")

#connect to mysql database
def connect_to_mysql_database():
    try:
        connection = mysql.connector.connect(host = "localhost", user = "priya", password = "priya", database = "mydatabase")
        if connection.is_connected():
            print("Connection to MySQL DB is successful!")
            return connection
    except Exception as e:
        print("Error while connection to MySQL DB", e)
        return None

#Check if DB exists or not
def create_db_if_not_exists(connection):
    try:
        cursor = connection.cursor()
        cursor.execute("CREATE DATABASE IF NOT EXISTS mydatabase;")
    except Exception as e:
        print("Error while creating DB", e)
        return None

# Create table if it doesn't exist
def create_table_if_not_exists(connection):
    cursor = connection.cursor()
    create_table_query = """
    CREATE TABLE IF NOT EXISTS QUESTIONS (
        id INT AUTO_INCREMENT PRIMARY KEY,
        subject_name VARCHAR(100),
        question_text TEXT,
        answer_options TEXT,
        correct_answer VARCHAR(10),
        chapter_name VARCHAR(100)
    );
    """
    cursor.execute(create_table_query)
    connection.commit()

# Extract questions and answers from PDF
def extract_questions_from_pdf(pdf_path):
    questions = []
    current_chapter = None

    try :
        pdffile_handler = open(pdf_path, "rb")
        #attach a reader object
        pdf_reader_data = PyPDF2.PdfReader(pdffile_handler)
        
        text = ""
        for page_index in range(len(pdf_reader_data.pages)):
            text += pdf_reader_data.pages[page_index].extract_text()

        # Regular Expression to capture Chapter Names
        chapter_pattern = re.compile(r"Chapter (\d+):\s*(.*?)(?=\s*Chapter \d+:|$)", re.DOTALL)
        chapters = chapter_pattern.findall(text)

        for chapter in chapters:
            print("\nchapter :: ", chapter)
            chapter_number, chapter_title = chapter
            #print("\nchapter_number :: ", chapter_number)
            #print("\nchapter_title :: ", chapter_title)
            current_chapter = chapter_title.strip()
            
            # Regular Expression to capture questions and options within a chapter
            question_pattern = re.compile(r"(\d+\.)\s*([^\n]+?)\s*(A\))\s*([^\n]+?)\s*(B\))\s*([^\n]+?)\s*(C\))\s*([^\n]+?)\s*(D\))\s*([^\n]+?)\s*Answer:\s*([A-D])\)", re.DOTALL)
            matches = question_pattern.findall(text)
            print("\nmatches :: ", matches)

            for match in matches:
                question_text = match[0].strip()
                #print("\nquestion_text :: ", question_text)
                options = [match[1].strip(), match[2].strip(), match[3].strip(), match[4].strip()]
                #print("\noptions :: ", options)
                correct_answer = match[5].strip()
                #print("\ncorrect_answer :: ", correct_answer)

                # Placeholder value for subject name (since this is Chemistry, we'll hardcode it)
                subject_name = "Chemistry"

                questions.append({
                    'subject_name': subject_name,
                    'question_text': question_text,
                    'answer_options': ', '.join(options),  # Store options as comma-separated string
                    'correct_answer': correct_answer,
                    'chapter_name': current_chapter
                })   
                print(f"\n questions : {questions}")
    except:
        if not os.path.exists(pdf_path):
            print(f"File is not found in path : {pdf_path}")
    
    return questions

# Insert questions into the database
def insert_questions_into_db(connection, questions):
    cursor = connection.cursor()
    insert_query = """
    INSERT INTO questions (subject_name, question_text, answer_options, correct_answer, chapter_name)
    VALUES (%s, %s, %s, %s, %s);
    """
    
    try:
        for question in questions:
            cursor.execute(insert_query, (
                question['subject_name'],
                question['question_text'],
                question['answer_options'],
                question['correct_answer'],
                question['chapter_name']
            ))
        connection.commit()
        print(f"{len(questions)} questions inserted successfully.")
    except Exception as e:
        print("Error inserting data into database", e)
        
def main():
    # Connect to MySQL Database
    connection = connect_to_mysql_database()
    
    if connection:
        create_db_if_not_exists(connection)
        # Create table if it doesn't exist
        create_table_if_not_exists(connection)

    # Extract questions from the PDF
    # 1.Store a PDF file in a folder called “/content” 
    download_link_url = "https://drive.google.com/file/d/1OVFr62PNO5-PcnWwFO1Frp0K_0UX6ENc/view?usp=drive_link"
    google_download_file_id = download_link_url.split("/")[5]
    # Corrected URL format for downloading the file
    actual_download_link_url = f'https://drive.google.com/uc?id={google_download_file_id}'
    work_folder = "./content"
    
    #download_file(work_folder, actual_download_link_url)

    pdf_path = os.path.join(work_folder, "Chemistry Questions.pdf")
    questions = extract_questions_from_pdf(pdf_path)

    if questions:
        # Insert extracted questions into the database
        insert_questions_into_db(connection, questions)

    # Close the database connection
    connection.close()

if __name__ == "__main__":
    main()
# Out:
# Connection to MySQL DB is successful!

# %%
#check tables in Database
import mysql.connector

mydb = mysql.connector.connect(host="localhost",
  user="priya",
  password="priya",
  database="mydatabase"
)

mycursor = mydb.cursor()
#mycursor.execute("select * from QUESTIONS")
#myresult = mycursor.fetchall()

#myresult

sql = "DROP TABLE Questions"

mycursor.execute(sql)
